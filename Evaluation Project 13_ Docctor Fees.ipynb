# %% [markdown]
# # Evalution Project 13
# Doctor consultation Fees

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We have a dataset which gives the important details about a doctor. Our aim is to build a model to predict the doctor's consulatation fees.

# %%
#creating two dataframes for testing and training from the csv files
ds_test=pd.read_excel('Final_Test.xlsx')
ds_train=pd.read_excel('Final_Train.xlsx')

# %%
#lets view the training dataset
ds_train
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# 2        Mathikere - BEL, Bangalore    ENT Specialist
# 3      Bannerghatta Road, Bangalore          Ayurveda
# 4             Keelkattalai, Chennai          Ayurveda
# ...                             ...               ...
# 5956        Basavanagudi, Bangalore    ENT Specialist
# 5957          Nungambakkam, Chennai  General Medicine
# 5958  Greater Kailash Part 2, Delhi  General Medicine
# 5959         Vileparle West, Mumbai  General Medicine
# 5960               Pitampura, Delhi           Dentist
#
#                                      Miscellaneous_Info  Fees
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100
# 1                 98% 76 Feedback Whitefield, Bangalore   350
# 2                                                   NaN   300
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250
# 4                 100% 4 Feedback Keelkattalai, Chennai   250
# ...                                                 ...   ...
# 5956            98% 45 Feedback Basavanagudi, Bangalore   300
# 5957                                                NaN   100
# 5958      97% 11 Feedback Greater Kailash Part 2, Delhi   600
# 5959  General Medical Consultation Viral Fever Treat...   100
# 5960  Acrylic Partial Denture Crowns and Bridges Fix...   200
#
# [5961 rows x 7 columns]

# %%
#lets check the columns
ds_train.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %% [markdown]
# ### Column Description:-
# 1. Qualification: Qualification and degrees held by the doctor
# 2. Experience: Experience of the doctor in number of years
# 3. Rating: Rating given by patients
# 4. Place: Area and the city where the doctor is located.
# 5. Profile: Type of the doctor
# 6. Miscellaeous_Info: Extra information about the doctor
# 7. Fees: Fees charged by the doctor

# %%
#lets check the datatypes of columns
print(ds_train.dtypes)              #training dataset
print('\n')
print(ds_test.dtypes)               #testing dataset
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object
#
#
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# dtype: object

# %%
#lets check for null values
print(ds_train.isnull().sum())            # training dataset
print('\n')
print(ds_test.isnull().sum())             # testing dataset
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64
#
#
# Qualification            0
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# dtype: int64

# %%
#checking the unique values of missing columns
#Rating
print(ds_train['Rating'].value_counts())
print('\n')
#Place
print(ds_train['Place'].value_counts())
print('\n')
#Miscellaneous_Info
print(ds_train['Miscellaneous_Info'].value_counts())
# Out:
# 100%    684
# 98%     290
# 99%     259
# 97%     241
# 96%     220
# 95%     178
# 94%     115
# 93%     109
# 92%      66
# 90%      66
# 91%      60
# 89%      42
# 88%      41
# 85%      27
# 82%      23
# 83%      21
# 86%      21
# 80%      19
# 77%      16
# 87%      14
# 84%      13
# 79%      13
# 67%      12
# 81%      12
# 71%       9
# 76%       9
# 75%       8
# 73%       8
# 60%       7
# 74%       7
# 78%       6
# 68%       5
# 56%       5
# 69%       4
# 70%       4
# 72%       3
# 57%       3
# 64%       2
# 55%       2
# 33%       2
# 62%       2
# 63%       2
# 40%       1
# 7%        1
# 58%       1
# 36%       1
# 45%       1
# 53%       1
# 47%       1
# 65%       1
# 48%       1
# Name: Rating, dtype: int64
#
#
# HSR Layout, Bangalore             75
# Andheri West, Mumbai              70
# Dwarka, Delhi                     67
# Banjara Hills, Hyderabad          64
# Mulund West, Mumbai               54
#                                   ..
# SV Road, Mumbai                    1
# TVM Fort, Thiruvananthapuram       1
# ECR Road, Chennai                  1
# Valiathura, Thiruvananthapuram     1
# Athani, Ernakulam                  1
# Name: Place, Length: 877, dtype: int64
#
#
# Acrylic Partial Denture Crowns and Bridges Fixing Artificial Teeth                      40
# Dental Fillings Zirconia Crowns Dental Implant Fixing                                   12
# Tooth Extraction Dental Fillings Scaling / Polishing                                    12
# Skin Allergy Treatment Skin Allergies Dermabrasion                                       9
# Skin Disease Treatment Kidney Stone Treatment Gall Bladder (Biliary) Stone Treatment     9
#                                                                                         ..
# 92% 7 Feedback Borivali West, Mumbai                                                     1
# 86% 19 Feedback Jayanagar 9 Block, Bangalore                                             1
# 100% 13 Feedback Kodambakkam, Chennai                                                    1
# Kondapur, Hyderabad ₹200 Visits Today                                                    1
# 98% 19 Feedback Dwarka, Delhi                                                            1
# Name: Miscellaneous_Info, Length: 2998, dtype: int64

# %%
#filling missing values
#Rating 
ds_train['Rating'].fillna('0%',inplace=True)
ds_test['Rating'].fillna('0%',inplace=True)
#Place
ds_train['Place'].fillna('Others,Others',inplace=True)
ds_test['Place'].fillna('Others,Others',inplace=True)
#Miscellaneous_Info
ds_train['Miscellaneous_Info'].fillna('Others,Others',inplace=True)
ds_test['Miscellaneous_Info'].fillna('Others,Others',inplace=True)

# %%
#lets again check for missing values
print(ds_train.isnull().sum())            # training dataset
print('\n')
print(ds_test.isnull().sum())             # testing dataset
# Out:
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# Fees                  0
# dtype: int64
#
#
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# dtype: int64

# %%
#converting experience into integers
#training dataset
ds_train['Experience']=ds_train['Experience'].str.split()
ds_train['Experience']=ds_train['Experience'].str[0].astype('int')
#testing dataset
ds_test['Experience']=ds_test['Experience'].str.split()
ds_test['Experience']=ds_test['Experience'].str[0].astype('int')

# %%
#checking the dataset
ds_train
# Out:
#                        Qualification  Experience Rating  \
# 0              BHMS, MD - Homeopathy          24   100%
# 1       BAMS, MD - Ayurveda Medicine          12    98%
# 2     MBBS, MS - Otorhinolaryngology           9     0%
# 3                BSc - Zoology, BAMS          12     0%
# 4                               BAMS          20   100%
# ...                              ...         ...    ...
# 5956                  MBBS, MS - ENT          19    98%
# 5957                            MBBS          33     0%
# 5958                            MBBS          41    97%
# 5959     MBBS, MD - General Medicine          15    90%
# 5960         BDS, MDS - Orthodontics          17   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# 2        Mathikere - BEL, Bangalore    ENT Specialist
# 3      Bannerghatta Road, Bangalore          Ayurveda
# 4             Keelkattalai, Chennai          Ayurveda
# ...                             ...               ...
# 5956        Basavanagudi, Bangalore    ENT Specialist
# 5957          Nungambakkam, Chennai  General Medicine
# 5958  Greater Kailash Part 2, Delhi  General Medicine
# 5959         Vileparle West, Mumbai  General Medicine
# 5960               Pitampura, Delhi           Dentist
#
#                                      Miscellaneous_Info  Fees
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100
# 1                 98% 76 Feedback Whitefield, Bangalore   350
# 2                                         Others,Others   300
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250
# 4                 100% 4 Feedback Keelkattalai, Chennai   250
# ...                                                 ...   ...
# 5956            98% 45 Feedback Basavanagudi, Bangalore   300
# 5957                                      Others,Others   100
# 5958      97% 11 Feedback Greater Kailash Part 2, Delhi   600
# 5959  General Medical Consultation Viral Fever Treat...   100
# 5960  Acrylic Partial Denture Crowns and Bridges Fix...   200
#
# [5961 rows x 7 columns]

# %%
#Extracting cities
#training dataset
ds_train['Place'] = ds_train['Place'].str.split(",")
ds_train['City'] = ds_train['Place'].str[-1]
ds_train['Place'] = ds_train['Place'].str[0]
#testing dataset
ds_test['Place'] = ds_test['Place'].str.split(",")
ds_test['City'] = ds_test['Place'].str[-1]
ds_test['Place'] = ds_test['Place'].str[0]

# %%
#lets check the unique values of qualification
print(ds_train['Qualification'].unique())          #training dataset
print('\n')
print(ds_test['Qualification'].unique())           #testing dataset
# Out:
# ['BHMS, MD - Homeopathy' 'BAMS, MD - Ayurveda Medicine'
#  'MBBS, MS - Otorhinolaryngology' ...
#  'MD - Dermatology , Venereology & Leprosy, MBBS, Fellowship In Dermatosurgery'
#  'BDS, certification in smile designing'
#  'MD - Homeopathy, Post Graduate Diploma in Healthcare Management(PGDHM), DHMS (Diploma in Homeopathic Medicine and Surgery)']
#
#
# ['MBBS' 'MBBS, Diploma in Otorhinolaryngology (DLO)' 'MBBS, DDVL' 'BAMS'
#  'BDS, MDS - Conservative Dentistry & Endodontics' 'BDS, MDS'
#  'BDS, MDS - Pedodontics'
#  'MD - Ayurveda Medicine, BAMS, Yoga Teachers Training Course, M. D. IN KAYACHIKISTA'
#  'BHMS' 'BDS' 'MBBS, FCD - Diabetology' 'MBBS, DDV'
#  'MBBS, MD - Dermatology' 'MS - ENT'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), MS - ENT, DNB - ENT, MNAMS (Membership of the National Academy)'
#  'BHMS, Diploma in Naturopathy & Yogic Science (DNYS), Diploma in Diet and Nutrition, Diploma in Cosmetology'
#  'MBBS, PG Diploma In Clinical Cosmetology (PGDCC)'
#  'BDS, MDS - Periodontics' 'BDS, MDS- Oral Pathology'
#  'MBBS, MD - General Medicine' 'MS - ENT, MBBS'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), DNB - ENT'
#  'MBBS, MS - ENT, DNB - Otorhinolaryngology'
#  'BDS, PhD - Endodontics, MDS - Conservative Dentistry & Endodontics'
#  'BSc, LCEH' 'BAMS, MD - Ayurveda Medicine'
#  'MBBS, DGO, MD - Obstetrics & Gynaecology' 'BHMS, MD - Homeopathy'
#  'BHMS, DM - Oncology'
#  'MBBS, DNB - Dermatology, Venereology & Leprosy, DVD'
#  'MBBS, MS - Otorhinolaryngology'
#  'Fellowship in Aesthetic Medicine, MD - Dermatology'
#  'BDS, Fellowship in Oral implantlogy'
#  'MBBS, MD - Dermatology, Fellowship in Aesthetic Medicine'
#  'MBBS, MS - Ophthalmology'
#  'MDS - Conservative Dentistry & Endodontics, BDS'
#  'MBBS, MS - Otorhinolaryngology, Diploma in Otorhinolaryngology (DLO)'
#  'BAMS, PGCR'
#  'BHMS, MS - Counselling and Psychotherapy, Certificate Course in Advanced Homoeopathy (C.C.A.H)'
#  'MBBS, MS - ENT, Diploma in Otorhinolaryngology (DLO)'
#  'MBBS, FRCS - Otolaryngology, Diploma in Otorhinolaryngology (DLO), Diploma in Acupuncture'
#  'MBBS, MD - Medicine, DM - Cardiology'
#  'BDS, Post-Graduate Certificate in Oral Implantology (PGCOI), MDS - Periodontology and Oral Implantology'
#  'LCEH' 'MBBS, MS - ENT' 'MBBS, MD - Medicine'
#  'DM - Nephrology, MD - Internal Medicine, MBBS' 'MBBS, DDVL, FRGUHS'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), FRCS - General Surgery'
#  'BDS, MDS - Oral & Maxillofacial Surgery, Fellowship in Cleft Lip & Palate, Fellowship in TMJ Surgery'
#  'MBBS, DNB - Otorhinolaryngology'
#  'Post Graduate Diploma in Diabetology (PGDD)(Madras Medical College), MBBS'
#  'Certificate in Dental Implants, MDS - Oral Medicine and Radiology, Certification in Aesthetic Dentistry, Certification in Full Mouth Rehabilitation, BDS'
#  'BDS, MDS - Orthodontics and Dentofacial Orthopaedics'
#  'MBBS, MD - Internal Medicine'
#  'MBBS, MD - General Medicine, DNB - General Medicine, Fellowship in Diabetology, DAA - Diploma in Allergy Asthma and Immunology, Certificate in Pulmonology'
#  'MD - Tuberculosis & Respiratory Diseases/Medicine, MBBS'
#  'MBBS, DDV, MD - Dermatology, Fellowship In Cosmetic Dermatology'
#  'B.Sc, MBBS, FCCP - Pulmonary Medicine' 'MBBS, MS - General Surgery'
#  'MBBS, MRCOG(UK), Diploma of the Faculty of Family Planning (DFFP), DRCOG, Member of the Royal College of General Practitioners UK (MRCGP), Fellowship in Diabetes (UK)'
#  'BDS, MDS - Paedodontics And Preventive Dentistry'
#  'BHMS, MS - Psychology' 'MD - General Medicine'
#  'BDS, Fellow of Academy of General Education (FAGE)' 'MD - Skin & VD'
#  'MBBS, MD - Dermatology , Venereology & Leprosy'
#  'BDS, MDS - Periodontology and Oral Implantology' 'MBBS, DNB'
#  'MDS - Orthodontics, BDS' 'BHMS, Diploma in Dermatology'
#  'MBBS, MD - Pulmonary Medicine, MD - Tuberculosis & Respiratory Diseases / Pulmonary Medicine'
#  'MDS - Prosthodontist And Crown Bridge, BDS'
#  'MBBS, Diploma in Orthopaedics'
#  'MBBS, DNB - ENT, Diploma in Otorhinolaryngology (DLO)'
#  'BDS, MDS - Prosthodontics'
#  'MD - Dermatology, MBBS, DNB - Dermatology, Venereology & Leprosy, FRGUHS'
#  'MDS - Oral & Maxillofacial Surgery, BDS' 'MBBS, MD - Dermatology, DDV'
#  'MBBS, Diploma in Aesthetic Medicine, DDV'
#  'MBBS, Diploma in Tuberculosis and Chest Diseases (DTCD), DNB -Chest, Post Graduate Diploma in Diabetes'
#  'BDS, MDS - Orthodontics' 'BDS, Diploma in Laser Dentistry, MDS'
#  'BDS, MDS - Oral Medicine and Radiology'
#  'MBBS, Diploma in Anesthesiology, Certificate in Acupuncture'
#  "BAMS, Yoga Instructor's Course, Diploma in Nutrition and Health Education"
#  'MD - Dermatology, DDV, MBBS'
#  'MBBS, DNB - Family Medicine, Fellowship in Diabetology'
#  'MBBS, MS - ENT, MRCS (UK), Diploma in Otorhinolaryngology (DLO)'
#  'DVD, MBBS' 'DDVL, MBBS' 'MBBS, MD - Obstetrics & Gynaecology'
#  'MBBS, Diploma in Dermatology'
#  'BHMS, PGDPC (Post Graduation Diploma In Psychological Counselling)'
#  'BAMS, PGD Yoga' 'MDS - Prosthodontics, BDS'
#  'BAMS, MBA - Healthcare Services' 'DNB - ENT, MD - Physician'
#  'MDS - Paedodontics And Preventive Dentistry, Membership of the Faculty of Dental Surgeons(MFDS)'
#  'MBBS, PGDHHM, PGDMLS' 'MBBS, DNB - Dermatology & Venereology'
#  'MBBS, MD - Obstetrics & Gynaecology, MRCOG(UK)'
#  'DNB - Otorhinolaryngology, MNAMS - General Surgery, MS - Otorhinolaryngology, MBBS'
#  'BDS, PhD - Orthodontics & Dentofacial Orthopaedics'
#  'MBBS, MD - Pediatrics' 'MD - Dermatology, MBBS'
#  'MBBS, MD - Internal Medicine, Post Graduate Diploma in Diabetology (PGDD)'
#  'BDS, Certificate of Oral Implantology'
#  'BDS, Doctor of Dental Surgery (DDS)'
#  'MBBS, Diploma in Dermatology, DDVL, DDV' 'MBBS, MD - Skin & VD, DDVL'
#  'MDS - Orthodontics and Dentofacial Orthopaedics'
#  'BHMS, Diploma in Cosmetology'
#  'MBBS, DDVL, DNB - Dermatology & Venereology, Fellowship In Dermatosurgery'
#  'BAMS, MBA - Hospital Management' 'MBBS, DDVL, MD - Dermatology'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), MS - ENT'
#  'MBBS, MD - Dermatology, Fellowship In Dermatosurgery'
#  'MD - Dermatology , Venereology & Leprosy, MBBS'
#  'MDS - Oral & Maxillofacial Surgery'
#  'MBBS, MD - Dermatology, FRGUHS, Fellowship in Cosmetology'
#  'MBBS, MS - ENT, FRCS, MRCS (UK), Dip Otolaryngology and Head and neck Surgery'
#  'MBBS, DNB - General Medicine, MF- Homeopathy, MSc - Psychotherapy And Counselling, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, DNB - Family Medicine, CCEBDM'
#  'MBBS, Diploma in Laparoscopy, FRCS - General Surgery (Upper GI)'
#  'MBBS, DNB - General Medicine, Post Graduate Diploma in Diabetology (PGDD)'
#  'Doctor of Homeopathic Medicine (HMD)'
#  'DHMS (Diploma in Homeopathic Medicine and Surgery), Diploma in Clinical Cosmetology, Diploma in Trichology - Cosmetology'
#  'BHMS, Post Graduate Diploma in Clinical Research (PGDCR)'
#  'BHMS, Certificate in Child Health (CCH)'
#  'MDS, Advanced Certificate Course in Dental Implants, BDS'
#  'BDS, MDS - Prosthodontist And Crown Bridge'
#  'DNB - General Medicine, MBBS' 'MBBS, MNAMS- Family Medicine'
#  'MBBS, MD - Internal Medicine, FACP (USA)'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), MD - Anatomy' 'BDS, FICD'
#  'FRCP, MRCPS, MBBS, MD - General Medicine, Diploma in Medical Law and Ethics (PGDMLE)'
#  'MBBS, MD - (Dermatology & STD)' 'MBBS, DVD, MD - Dermatology'
#  'MBBS, Diploma in Emergency Medicine'
#  'BDS, MBA, Certification in Aesthetic Dentistry'
#  'MBBS, Fellow of Academy of General Education (FAGE), MS - ENT, Fellowship in Advanced Endoscopic Sinus Surgery'
#  'BSc, DHMS (Diploma in Homeopathic Medicine and Surgery)'
#  'BHMS, Doctor of Homeopathic Medicine (HMD), MBA'
#  'MDS - Oral & Maxillofacial Surgery, Fellowship Program in Oral Implantology and LASER Dentistry, BDS'
#  'MBBS, MS - ENT, Fellowship in Head & Neck Surgery'
#  'BDS, MDS - Prosthodontist & Oral Implantologist'
#  'MD - Internal Medicine, MBBS, Diplomate from the American Board of Internal Medicine'
#  'BAMS, MD - Ayurveda Medicine, PhD- Ayurveda'
#  "BAMS, PGD ND, Yoga Instructor's Course"
#  'BDS, Fellowship Program in Aesthetic Dentistry and Occlusion'
#  'MBBS, Diploma in Public Health, MD - Community Medicine, Fellowship in Lifestyle Medicine'
#  'BAMS, MS - Ayurveda'
#  'Diploma in Otorhinolaryngology (DLO), Ph. D - ENT, MBBS, DNB - ENT'
#  'MDS - Orthodontics and Dentofacial Orthopaedics, BDS'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), MS - Otorhinolaryngology'
#  'BSAM, BAMS, Fellow of Academy of General Education (FAGE)'
#  'MD - Homeopathy, BHMS' 'MBBS, DNB - Otorhinolaryngology, DLO'
#  'Get inspired by remarkable stories of people like you'
#  'MBBS, MD - General Medicine, Diploma in Diabetology'
#  'MD - Ayurveda Medicine'
#  'MD - Homeopathy, PG Diploma In Clinical Cosmetology (PGDCC), BHMS'
#  'DHMS (Diploma in Homeopathic Medicine and Surgery)' 'MD - Dermatology'
#  'MBBS, DDV, DNB' 'BDS, Post graduate diploma in Hospital Management'
#  'MBBS, Diploma in Anesthesiology'
#  'BDS, MDS - Oral & Maxillofacial Surgery, FDSRCS - Fellowship in Dental Surgery'
#  'MBBS, MD - Internal Medicine, Post Graduate Diploma in Diabetology (PGDD), DNB - General Medicine'
#  'BHMS, PG - Homeo, Integrated therapy in Cancer, Basic Course in Palliative Care'
#  'BHMS, Fellowship Course in Homoeopathic Dermatology, Masters in Counselling and Psychotherapy'
#  'MBBS, MD - Medicine, FCPS - General Surgery' 'BHMS, CSD'
#  'BHMS, MD (HOM) - Paeditrics, Fellowship Course in Homoeopathic Dermatology'
#  'M.S. (Ayurved) Stri Roga & Prasuti Tantra, BAMS'
#  'MBBS, MD - General Medicine, DNB - General Medicine'
#  'MBBS, MS - Otorhinolaryngology, Fellowship in laryngology'
#  'BDS, MDS - Prosthodontist And Crown Bridge, Certificate Course in Orthodontics'
#  'B.Sc, BAMS, MD - Ayurveda Medicine' 'DO, MS - Ophthalmology, MBBS'
#  'FRCS - General Surgery' 'BDS, MDS- Periodontist & Implantalogist'
#  'MBBS, MCh - Surgical Gastroenterology/G.I. Surgery'
#  'BDS, Certificate in Dental Implants' 'MBBS, DNB - General Medicine'
#  'MDS - Paedodontics And Preventive Dentistry, BDS'
#  'MBBS, Diploma in Tuberculosis and Chest Diseases (DTCD)'
#  'BAMS, MS - Ayurvedic General Surgery'
#  'MBBS, MD - Physician, DNB - General Medicine, Fellowship in Diabetology'
#  'MBBS, DNB - Internal Medicine' 'MBBS, FICA, MD - General Medicine'
#  'BDS, MDS - Periodontology and Oral Implantology, Current Concepts in American Dentistry Advances in Implantology and Oral Rehabilitation, Comprehensive Course in Modern Endodontics'
#  'MBBS, FACC, FCCP - Pulmonary Medicine' 'FWFO, FPFA'
#  'MBBS, MD - Internal Medicine, DM - Gastroenterology'
#  'MBBS, MD - General Medicine, DM - Cardiology' 'MBBS, DLO, MS - ENT'
#  'MS - ENT, Diploma in Otorhinolaryngology (DLO)'
#  'MBBS, Diploma in Family Medicine (DFM), Fellowship in Diabetology'
#  'BHMS, Diploma in Medical Cosmetology'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), DNB - Otorhinolaryngology'
#  'MBBS, DDVL, Fellowship in Dermatological Laser Surgery, Fellowship In Cosmetic Dermatology'
#  'MBBS, MD - Family Medicine, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, MSc' 'Diploma in Otorhinolaryngology (DLO), MS - ENT, MBBS'
#  'MBBS, Diploma in Family Medicine (DFM)' 'MD - General Medicine, MBBS'
#  'DNB - ENT, Diploma in Otorhinolaryngology (DLO), MBBS'
#  'MBBS, MD - Dermatology, MD - Dermatology , Venereology & Leprosy'
#  'MBBS, Diploma in Child Health (DCH), DNB - Paediatrics' 'BSc, BHMS'
#  'BAMS, MD- Ayurveda Rasashastra'
#  'BAMS, PG Dip (Medical Education), Fellow of Academy of General Education (FAGE), MBA (Health Care)'
#  'MS - Otorhinolaryngology, MBBS'
#  'BAMS, MD - Alternate Medicine, Fellow of Academy of General Education (FAGE), Diploma in Preventive & Promotive Healthcare'
#  'BHMS, MD - General Medicine'
#  'MDS - Oral & Maxillofacial Surgery, Implant Training Course- Nobel Biocare, BDS'
#  'MBBS, Diploma in Dermatology, MD - Dermatology'
#  'MBBS, Certificate Course in Evidence Based Diabetes Management (CCEBDM)'
#  'DDVL' 'BHMS, DNHE' 'BAMS, Diploma in Clinical Nutrition'
#  'BHMS, MD - Alternate Medicine, Masters in Counselling and Psychotherapy'
#  'MBBS, MD - Internal Medicine, Post Graduate Diploma in Diabetology (PGDD), Fellowship in Diabetology'
#  'Diploma in Otorhinolaryngology (DLO), MBBS'
#  'MBBS, DNB - ENT, MS - ENT, FCPS - Oto-Rhino-Laryngology, Diploma in Otorhinolaryngology (DLO)'
#  'BDS, MDS - Paedodontics And Preventive Dentistry, Certification for Professional Chemical Peel Workshop'
#  'BHMS, Diploma in Cosmetology, MD - Dermatology'
#  'BAMS, M. D. IN KAYACHIKISTA' 'MBBS, MD - Pharmacology'
#  'MBBS, Fellowship of College of General Practice (FCGP)'
#  'MDS - Periodontology and Oral Implantology, BDS'
#  'MD - Homeopathy, PGDPC (Post Graduation Diploma In Psychological Counselling)'
#  'MBBS, DNB - Family Medicine'
#  'MBBS, MS - ENT, Diploma in Aesthetic Medicine'
#  'BDS, Post-Graduate Certificate in Oral Implantology (PGCOI)'
#  'BDS, MDS - Oral & Maxillofacial Surgery'
#  'MDS - Prosthodontist And Crown Bridge' 'MD - Homeopathy, BHMS, DNHE'
#  'MBBS, MD - Dermatology, Fellow of the American Academy of Dermatology (FAAD)'
#  'BAMS, MBA (HCS)' 'MBBS, DVD'
#  'MBBS, Diploma in Anesthesiology, Postgraduate Diploma Clinical Cardiology (PGDCC)'
#  'BHMS, MD - Ayurveda Medicine'
#  'MBBS, MASTERS IN MEDICAL SCIENCE AND TECHNOLOGY'
#  'DNB - Dermatology & Venereology, MBBS'
#  'BDS, MDS-Oral Pathology and Oral Microbiology' 'MBBS, MS - ENT, DNB'
#  'MBBS, Post Graduate Diploma in Diabetes, Fellowship in Diabetology'
#  'MD - Homeopathy, DHMS (Diploma in Homeopathic Medicine and Surgery)'
#  'MBBS, MS - ENT, DNB - ENT' 'MBBS, DDV, Diploma in Health Administration'
#  'BDS, Advanced Certificate Course in Dental Implants'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), Fellow of Academy of General Education (FAGE), FRCS - General Surgery'
#  'BDS, MDS - Periodontics, Fellowship and Diplomate in Implantology from ICOI (USA), DICOI'
#  'MD - Dermatology , Venereology & Leprosy' 'BHMS, PGDHA'
#  'MBBS, MD - General Medicine, MRCP - General Medicine'
#  'BDS, MDS - Periodontics, MSc'
#  'BDS, Certification in Aesthetic Dentistry'
#  'MBBS, MD - Homeopathy, MD - General Medicine' 'MDS - Pedodontics, BDS'
#  'MBBS, MD - Dermatology, DNB - Dermatology & Venereology, F.C.P.S (Dermatology)'
#  'MD - Homeopathy'
#  'BDS, MDS - Oral & Maxillofacial Surgery, Training in Surgical Oncology'
#  'MBBS, MD - General Medicine, FCD - Diabetology'
#  'MBBS, Post Graduate Course in Diabetology, DipFM'
#  'Diploma in Child Health (DCH), MBBS'
#  'MD - General Medicine, DNB, Diploma in Geriatric Medicine'
#  'BAMS, Certificate Course in Kshar Sutra Surgery'
#  'MBBS, DORL (ENT), MS - ENT' 'MBBS, MD - Dermatology, DNB'
#  'MBBS, MD - General Medicine, Diploma in Cardiology'
#  'MBBS, MD - Oncology' 'BHMS, MD - Homeopathy, MA - Clinical Psychology'
#  'Diploma in Dermatology, MD - Dermatology'
#  'MBBS, PG in Diabetology, FCCP'
#  'MBBS, Diploma in Child Health (DCH), Diploma of The Australian Institute of Dermatology, PG Diploma in Endocrinology'
#  'MBBS, MD - Medicine, DM - Cardiology, FACC, FESC'
#  'BSc - Dietitics / Nutrition, MBBS, Diploma in Child Health (DCH)'
#  'MBBS, Diploma in Tuberculosis and Chest Diseases (DTCD), DNB - General Medicine'
#  'BHMS, MSc' 'MBBS, MD - General Medicine, CCEDM'
#  'BDS, MDS, Fellowship in Oral implantlogy'
#  'MBBS, MD - General Medicine, DM - Cardiology, FIAMS'
#  'BAMS, Certificate in Food and Nutrition, Diploma in Dietatics & Clinical Nutrition'
#  'MBBS, DNB - General Medicine, Fellowship in Diabetology(Johns Hopkins University School of Medicine, USA)'
#  'DDVL, Diploma in Dermatology' 'Diploma in Hospital Administration, BAMS'
#  'BAMS, MS - Ayurveda, Certificate in Child Health (CCH)'
#  'MBBS, MD - Internal Medicine, DNB - General Medicine, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, DDVL, Fellowship in Cosmetology and Dermatosurgery, Fellowship in Aesthetic Medicine'
#  'MBBS, MS - General Surgery, MS - Paediatrics Surgery'
#  'MBBS, MD - Dermatology, DVL - Dermatology & Venereology'
#  'MBBS, Post Graduate Course in Diabetology, FCPS - General Surgery'
#  'DMS, MD - Homeopathy' 'MDS, BDS' 'MDS - Pedodontics'
#  'BAMS, BSAM, MS - Counselling & Psychotherapy'
#  'MBBS, Advanced Certificate Course In Diabetes, PG in Diabetology, Post Graduate Diploma in Diabetology (PGDD)(University of Leicester, UK)'
#  'B.Sc, MBBS, MD - General Medicine, Master of Clinical Embryology, Diploma of Clinical Hypnotherapy'
#  'BDS, B.Sc - Zoology (Hons.)'
#  'MBBS, Fellowship in Diabetology, Diploma in Emergency Medicine'
#  'MBBS, PGD ND'
#  'DHMS (Diploma in Homeopathic Medicine and Surgery), MD - Homeopathy'
#  'MBBS, MD - Skin & VD'
#  'BHMS, Certificate Course in Advanced Homoeopathy (C.C.A.H), Post Graduate Diploma in Emergency Medical Services'
#  'BHMS, PG - Homeo' 'MBBS, DDV, FCPS - Dermatology, Venereology & Leprosy'
#  'B.Sc, BHMS, Certificate in Food and Nutrition, Certificate Course in Advanced Homoeopathy (C.C.A.H)'
#  'MBBS, MD - General Medicine, DNB - Nephrology'
#  'MBBS, MD - Dermatology, MNAMS - DERMATOLOGY, Diploma in Dermatology'
#  'MBBS, MD - Family Medicine'
#  'BAMS, Post Graduate Diploma in Emergency Services (PGDEMS), MS - Psychology'
#  'BHMS, CGO' 'MBBS, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, MD - General Medicine, DDV'
#  'MBBS, Fellowship in Emergency Medicine, Post Graduate Diploma in Diabetology (PGDD)(Madras Medical College), PG Diploma in Endocrinology'
#  'BDS, Professional Implantology Training Course (PITC), Advanced Surgical Training In Implants, Certification in Full Mouth Rehabilitation'
#  'MS - ENT, DNB - ENT' 'MBBS, MS - General Surgery, MCh - Neuro Surgery'
#  'MS - Otorhinolaryngology, DNB - Otorhinolaryngology, FCPS - Mid. & Gynae, MBBS'
#  'MBBS, Post Graduate Diploma in Diabetology (PGDD), MD - General Medicine'
#  'DNB - Family Medicine, MBBS, DHM' 'MBBS, Diploma in Child Health (DCH)'
#  'MDS - Operative Dentistry, BDS'
#  'BDS, Post Graduate Diploma In Aesthetic & Restorative Dentistry'
#  'MBBS, DDV, MD - Skin & VD' 'MBBS, DNB - ENT, DNB - Otorhinolaryngology'
#  'MBBS, MS - ENT, MCh - Oncology'
#  'MD - General Medicine, FRCP, FIAMS, MBBS'
#  'BDS, Diploma in Hospital Administration' 'MBBS, DM - Neurology'
#  'MS - ENT, DNB - ENT, MBBS'
#  'MBBS, MS - Otorhinolaryngology, MS - ENT, Fellowship in Rhinology and Endoscopic Skull Base Surgery, Fellowship in Head & Neck Surgery'
#  'MBBS, DDV, MD - Skin,VD & Leprosy'
#  'Post Graduate Certificate in Endodontics (PGCE), BDS'
#  'MBBS, D.D, MD - Dermatology'
#  'MBBS, MD - Dermatology, PhD - Dermatology & Venereology' 'BSAM'
#  'MBBS, MD - Dermatology, Fellowship in Dermatological Laser Surgery'
#  'MBBS, MD - Microbiology' 'BAMS, PG in Clinical Nutrition and Dietetics'
#  'MD-DVL, MBBS, DNB - Dermatology & Venereology'
#  'MBBS, MS - General Surgery, Diploma in Otorhinolaryngology (DLO)'
#  'MBBS, DNB - Obstetrics & Gynecology'
#  'MBBS, Diploma of the Faculty of Family Planning (DFFP), Diploma in Practical Dermatology, MRCGP'
#  'MBBS, DDV, Fellow of Academy of General Education (FAGE)'
#  'MBBS, Diploma in Cosmetology'
#  'MS - ENT, MBBS, DNB - Otorhinolaryngology' 'MS - Ayurveda, BAMS'
#  'MBBS, DDVL, Certificate of Completion of Specialist Training- Transplant Surgery (CCST-TS)'
#  'MBBS, MD - General Medicine, DM - Cardiology, Fellowship In Interventional Cardiology'
#  'MBBS, DNB - Dermatology & Venereology, Fellow of the American Academy of Dermatology (FAAD), DVD'
#  'MBBS, Fellowship in Diabetology' 'BAMS, MS - Psychology'
#  'MBBS, MS - MS.Medicine'
#  'MBBS, MD - Dermatology, Diploma in Medical Law and Ethics (PGDMLE), Diploma in Medical Cosmetology'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, FRGUHS'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), FAMS - Fellowship of the Academy Medicine'
#  'BDS, MDS - Prosthodontist & Oral Implantologist, Fellowship in Oral implantlogy'
#  'Diploma in Otorhinolaryngology (DLO), MBBS, DNB'
#  'BHMS, Post Graduate Diploma in Emergency Services (PGDEMS), PGDPC (Post Graduation Diploma In Psychological Counselling)'
#  'MBBS, DDV, DDVL' 'MBBS, MS - Orthopaedics' 'BDS, MDS - Endodontics'
#  'MBBS, Post Graduate Diploma in Maternity and Child Health (PGDMCH)'
#  'B.Sc, MSc, MBBS' 'BDS, Master of Public Health (MPH)'
#  'BHMS, Diploma in Nutrition and Health Education' 'MBBS, DGO'
#  'MBBS, Fellowship in Nephrology' 'MBBS, Diploma in Diabetology'
#  'BAMS, Post Graduate Diploma in Clinical Research (PGDCR)'
#  'BDS, Certificate Course in Implantology'
#  'BDS, Diploma in Health Administration' 'BDS, MBA (Health Care)'
#  'Diploma in Aesthetic Medicine, Certificate in Aesthetic Medicine, Diploma in Practical Dermatology, MBBS'
#  'MDS - Paedodontics And Preventive Dentistry, BDS, Certified in Inhalational Sedation'
#  'BHMS, PG Diploma in Preventive and Promotive Health Care (PGD PPHC), MSc. - Food Service Management & Dietetics, Certificate in Yoga & Meditation'
#  'MBBS, MD - Physiology, AFIH, Diploma in Diabetes Management Certificate Program'
#  'MBBS, MD - General Medicine, Post Graduate Diploma in Diabetology (PGDD), Post Graduate Diploma in Diabetology (PGDD)'
#  'MD - Ayurveda Medicine, BAMS'
#  'MBBS, DVD, DNB - Dermatology & Venereology'
#  'BDS, Certificate in Dental Implants, Certificate in Cosmetic Dentistry'
#  'MBBS, DDVL, DNB - Dermatology & Venereology, MNAMS (Membership of the National Academy)'
#  'BAMS, Post Graduate Diploma in Psychological Counseling'
#  'Diploma in Dermatology' 'BDS, MDS - Public Health Dentistry'
#  'MD - Dermatology , Venereology & Leprosy, DNB - Dermatology & Venereology'
#  'MBBS, DDVL, Certificate in Cosmetology'
#  'BHMS, PG - Homeo, Diploma in Diet and Nutrition' 'MBBS, DOMS'
#  'MS - Otorhinolaryngology, DNB - ENT, MBBS'
#  'BSc - Zoology, MBBS, Diploma in ENT, MS - ENT'
#  'MBBS, Diploma in Clinical Dermatology (UK)'
#  'Diploma in Ayurvedic Medicine (DAM)'
#  'MBBS, M.Med in Family Medicine, post graduate diploma in health Sciences in diabetology'
#  'MBBS, MS - ENT, Diploma in ENT'
#  'MBBS, Post Graduate Diploma in Dermotology (PGDD)'
#  'BAMS, MD - Alternate Medicine, Post Graduate Diploma in Clinical Research (PGDCR), Certificate in Aesthetic Medicine, Yoga Teachers Training Course, Certified in Ayurveda Approach to Diabetes mellitus, Certified in Ayurveda Beauty care'
#  'MBBS, DNB, DDVL' 'BAMS, PG Diploma in Panchakarma'
#  'MBBS, DNB, Master of Hospital Administration' 'BHMS, MD - Medicine'
#  'MBBS, DNB - Respiratory Diseases, FCCP - Pulmonary Medicine, DAA - Diploma in Allergy Asthma and Immunology, P.G Diploma in Diabetes Management, Fellowship in Clinical Cardiology'
#  'MBBS, MD - Dermatology, Diploma in Aesthetic Medicine, Diploma in International Academy of Aesthestic Medicine'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, DNB - Dermatology & Venereology'
#  'MBBS, MS - General Surgery, DNB, FRCS - General Surgery, MCh - Surgical Gastroenterology/G.I. Surgery'
#  'BPTh/BPT, Masters Of Physiotheraphy, BAMS'
#  'MBBS, MD - Dermatology, Diploma in Dermatology'
#  'MBBS, MRCGP, Diploma in Child Health (DCH), DRCOG, Diploma of the Faculty of Family Planning (DFFP)'
#  'BDS, MDS - Operative Dentistry'
#  'MBBS, MD - Dermatology, Fellow of Academy of General Education (FAGE)'
#  'MBBS, MD - Dermatology, FRGUHS' 'BAMS, Diploma in Hospital Management'
#  'DDVL, MD - Dermatology , Venereology & Leprosy'
#  'BDS, Certificate in Orthodontics'
#  'MD - General Medicine, DNB - General Medicine, MBBS, European Diploma in Intensive Care Medicine (EDIC), Fellowship in Diabetology'
#  'MBBS, MD - TB & Chest' 'MBBS, DDVL, DNB - Dermatology & Venereology'
#  'MBBS, FRCS - Otolaryngology' 'BDS, MDS - Oral Medicine'
#  'MBBS, Diploma in Orthopaedics, MS - Orthopaedics'
#  'MD - Homeopathy, Diploma in Acupuncture'
#  'BDS, Fellowship in Aesthetic Medicine' 'MBBS, MD - Physician'
#  'MBBS, MD - General Medicine, Post Graduate Diploma in Diabetology (PGDD), Fellowship In Critical Care, Fellowship in Rheumatology'
#  'BDS, Fellowship in Oral implantlogy, Diploma in Laser Dentistry, Fellowship and Diplomate in Implantology from ICOI (USA)'
#  'MBBS, MD - Skin,VD & Leprosy' 'BAMS, Diploma in Emergency Medicine'
#  'BDS, PG Diploma in Conservative, Endodontics and Aesthetic Dentistry, Fellowship In Clinical Cosmetology, PG Diploma In Clinical Cosmetology (PGDCC), MBA - Hospital Management, Diploma in Cosmetic Dentistry, Fellow of Academy of General Education (FAGE), Advanced Retreatment Course in RCT, Advanced Endotontic Course On Root Canal, Certified Course in Oral Surgery, MIDA, Certification in Prosthodontics & Periodontology, Certified Advanced Course in Wisdom Tooth Extraction, Certificate in Cosmetic Dentistry, Fellowship in Aesthetic Dentistry (FAD), Post Graduate Certificate in Endodontics (PGCE)'
#  'FAMS - Fellowship of the Academy Medicine, MBBS, MS - ENT, Diploma in ENT, Specialized Training in Otology, Fellowship in Head & Neck Oncology Surgery, Advanced Endoscopy Training, Cochlear Implant Surgery, Advance Course on Diagnosis of Allergy and Immunotherapy'
#  'BDS, MDS - Conservative Dentistry & Endodontics, MD - Dental Laser'
#  'BHMS, MD - Homeopathy, MS - Counselling and Psychotherapy'
#  'BAMS, Fellowship in Medical Cosmetology' 'MDS - Periodontics, BDS, MDS'
#  'MBBS, MD - General Medicine, DM - Gastroenterology'
#  'MBBS, MS - Otorhinolaryngology, DNB'
#  'Diploma in Dermatology, MD - Skin,VD & Leprosy, MBBS'
#  'MBBS, MD - Alternate Medicine'
#  'BHMS, BHMS, Certificate in Child Health (CCH)'
#  'MBBS, MD - Aerospace Medicine, DIH, Diploma in Hospital Administration, Fellowship of College of General Practice (FCGP)'
#  'BDS, MDS - Orthodontics and Dentofacial Orthopaedics, Certificate of Oral Implantology'
#  'BHMS, MD - Alternate Medicine' 'MD - Skin & VD, MBBS'
#  'BAMS, Fellow of Academy of General Education (FAGE), Post Graduate Diploma In Yoga'
#  'MBBS, MSc - Clinical Dermatology'
#  'MBBS, Post Graduate Diploma in Medical Law and Ethics, Msc Clinical Research & Regulatory Affairs, Diploma in Family Medicine (DFM)'
#  'BDS, PGCAD'
#  'MBBS, MD - Cardiology, DM - Cardiology, FCCP - Pulmonary Medicine'
#  'DHMS (Diploma in Homeopathic Medicine and Surgery), Diploma in Trichology - Cosmetology, Diploma in Obesity & Pain management'
#  'BHMS, Diploma in Diet and Nutrition'
#  'MBBS, FCPS - Dermatology, Venereology & Leprosy'
#  'BDS, Certification in Clear Aligners, MDS - Orthodontics'
#  'MBBS, MD - General Medicine, Fellowship in Diabetes (UK), CCEBDM, CCT - Endocrinology and Diabetes Mellitus'
#  'MBBS, DNB - Dermatology & Venereology, DDV, DVD'
#  'MBBS, Fellowship in Diabetology, Certificate Course in Gestational Diabetes Mellitus'
#  'BHMS, MD - Homeopathy, MBA - Hospital Management'
#  'MBBS, DNB - Internal Medicine, M.H.Sc-Diabetology'
#  'DNB - Dermatology, Venereology & Leprosy, MBBS, DDVL'
#  'DNB - Pediatrics, MBBS'
#  'M.D. (Ayu.), Panchkarma, Consultant Rheumatologist (Ayu.), DYSc., BAMS'
#  'MBBS, Diploma in Clinical Dermatology (UK), Diploma In Skin Aesthetics'
#  'MBBS, MD - Medicine, DM - Nephrology'
#  'MBBS, MS - General Surgery, MD - Medicine'
#  'MD - Dermatology , Venereology & Leprosy, DNB, MRCP (UK)'
#  'MBBS, DDV, DNB, MD - Dermatology'
#  'MBBS, MS - ENT, Fellowship In Phonosurgery' 'Diploma in ENT, MBBS'
#  'BHMS, MD - Medicine, PhD - Medicine'
#  'BHMS, Certificate in Food and Nutrition'
#  'BAMS, DNHE, Certification In Yoga' 'MBBS, DLO, DNB - ENT'
#  'MBBS, MD - General Medicine, DM - Medical Oncology'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, Fellowship In Dermatosurgery, Certificate Course In Cosmetic Dermatology & Lasers'
#  'MD - Practice Of Medicine, BHMS, Diploma in Trichology - Cosmetology, Certificate in Child Health (CCH), CGO, MBBS'
#  'MBBS, DPM (Psychiatry)'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), MS - ENT, FRCS - General Surgery'
#  'MBBS, MD - Community Medicine'
#  'MBBS, MD - General Medicine, Post Graduate Diploma in Diabetology (PGDD)(Madras Medical College)'
#  'MD - Dermatology, DNB - Dermatology & Venereology, MBBS'
#  'MS - Otorhinolaryngology, DNB - ENT, DHM, MBBS'
#  'B.Sc, BAMS, MD - Yoga and Rehab' 'MBBS, MD - Skin & VD, MAMS'
#  'MBBS, PG Diploma In Emergency Trauma Care, ACLS'
#  'MBBS, DDVL, Fellowship in Pediatric Dermatology'
#  'MBBS, DNB - Dermatology, Venereology & Leprosy'
#  'MBBS, DDVL, Fellowship IN FUE Hair Transplant Technique'
#  'MBBS, Postgraduate Diploma Clinical Cardiology (PGDCC), PG Diploma in Human Rights'
#  'MBBS, DNB - Paediatrics, Diploma in Child Health (DCH)'
#  'MBBS, Diploma in Dermatology, Diploma in Medical Cosmetology'
#  'MBBS, DDVL, AFIH' 'MBBS, MS - Otorhinolaryngology, MS - ENT'
#  'MD - Panchakarma, BAMS' 'DNB - General Medicine, MD - Physician'
#  'MBBS, MD - Family Medicine, Post Graduate Diploma in Diabetes, Certification Course In Diabetes'
#  'MD - Dermatology , Venereology & Leprosy, Fellow of the American Academy of Dermatology (FAAD), MBBS'
#  'MD - Homeopathy, PGCR'
#  'BDS, MDS - Endodontics, Certification in Laser Dentistry'
#  'MBBS, Diploma in Otorhinolaryngology (DLO), DNB - Ophthalmology'
#  'BAMS, MD - Ayurveda Medicine, Fellowship in Sexual Medicine, Fellowship in Rheumatology'
#  'MBBS, MD - Dermatology, DNB - Dermatology & Venereology, Fellowship in Cosmetology'
#  'MDS - Community Dentistry, BDS' 'MBBS, DNB - Nephrology'
#  'MBBS, MD - General Medicine, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, MD - General Medicine, Post Graduate Diploma in Diabetology (PGDD), Certificate Course in Evidence Based Diabetes Management (CCEBDM), FRCP'
#  'BAMS, MD-Ayurvedic Vachaspati'
#  'BAMS, MD - Ayurveda Medicine, MBA - Hospital Management'
#  'MBBS, DNB - ENT, Fellowship in Neuro-Otology and Skull Base Surgery (USA)'
#  'BDS, MDS - Orthodontics and Dentofacial Orthopaedics, Certificate of Oral Implantology, Fellowship in Aesthetic Medicine, Invisalign Training Course'
#  'MBBS, MS - General Surgery, FRCS - General Surgery, MCh - Urology, DNB - Urology/Genito - Urinary Surgery'
#  'MBBS, AFIH, Fellowship in Diabetology'
#  'BDS, MDS - Prosthodontist And Crown Bridge, Fellowship in Oral implantlogy'
#  'MBBS, DVL, MD - Dermatology , Venereology & Leprosy'
#  'BHMS, Fellowship in Medical Cosmetology (FMC)'
#  'MBBS, MD - Dermatology, DNB - Dermatology & Venereology'
#  'MBBS, DDVL, Fellowship In Dermatosurgery'
#  "BAMS, Master of Arts - Yoga, Yoga Instructor's Course"
#  'MBBS, MS - Otorhinolaryngology, Fellowship in Head & Neck Oncology Surgery, Fellowship in Skull Base Surgery, Fellowship in Head & Neck Oncology Surgery'
#  'PhD - Orthodontics & Dentofacial Orthopaedics, BDS' 'FICD'
#  'MBBS, BDS, FDSRCS - Fellowship in Dental Surgery'
#  'MDS - Endodontics, BDS'
#  'MS - ENT, Diploma in Otorhinolaryngology (DLO), Diploma in Opthalmology, MBBS'
#  'BHMS, M.Phil - Psychology, MSc - Applied Psychology'
#  'MS - Otorhinolaryngology, Diploma in Otorhinolaryngology (DLO)'
#  'MBBS, DNB - ENT'
#  'MBBS, MS - Otrohinolaryngology, DNB - Otorhinolaryngology'
#  'MD - Internal Medicine, MBBS' 'DNB - ENT, MS - ENT, MBBS'
#  'BDS, MDS - Prosthodontist And Crown Bridge, FICOI'
#  'MBBS, MS - Otorhinolaryngology, Diploma in Otorhinolaryngology (DLO), Diploma in Health Administration'
#  'DEHM, BEMS' 'BDS, MDS - Conservative Dentistry & Endodontics, DNB'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, DDV' 'BAMS, MSc - Yoga'
#  'MBBS, DPH & H'
#  'BHMS, Certificate Course in Advanced Homoeopathy (C.C.A.H)'
#  'MD - Medicine, MBBS'
#  'MBBS, DDV, Fellowship in Dermatological Laser Surgery'
#  'MBBS, DNB - Pediatrics, Fellowship in Paediatric gastroenterology & Hepatology, Fellowship In Transplant Hepatology'
#  'DNB - Dermatology & Venereology, MNAMS - DERMATOLOGY, F.C.P.S (Dermatology), DDV, MBBS'
#  'MS - Otorhinolaryngology, DNB - Otorhinolaryngology, MBBS'
#  'MBBS, MD - General Medicine, DNB' 'DDVL, MBBS, F.A.M'
#  'BAMS, MD - Internal Medicine, Diploma in Emergency Medicine, Post Graduate Diploma In Yoga'
#  'MBBS, Post Graduate Diploma in Diabetology (PGDD), PG in Diabetology(Johns Hopkins University School of Medicine, USA)'
#  'BHMS, Post Graduate Diploma In Yoga'
#  'MBBS, MD - General Medicine, DNB - Neurology' 'LCEH, MD - Homeopathy'
#  'MRCGP, Post Graduate Diploma in Diabetology (PGDD)(University of Leicester, UK), MBBS'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, MRCPS' 'MDS'
#  'MBBS, Post Graduate Diploma in Diabetology (PGDD), Certificate Course in Evidence Based Diabetes Management (CCEBDM)'
#  'MBBS, MS - ENT, Diploma in Otorhinolaryngology (DLO), FRCS - General Surgery'
#  'MBBS, MD - General Medicine, DM - Nephrology'
#  'MBBS, MD - Dermatology, DVL'
#  'BHMS, MD - Homeopathy Psychiatry, Post Graduate Diploma in Clinical Research (PGDCR), MS - Psychology'
#  'BAMS, MS - Counselling and Psychotherapy'
#  'FPFA, BDS, FPFA, MDS - Conservative Dentistry & Endodontics'
#  'MBBS, MD - Internal Medicine, DNB - General Medicine'
#  'DHMS (Diploma in Homeopathic Medicine and Surgery), PhD - Homoeopathy'
#  'MBBS, Fellow of Academy of General Education (FAGE), BSc - Dietitics / Nutrition'
#  'MBBS, MS - Otorhinolaryngology, DNB - Otorhinolaryngology'
#  'MBBS, Post Graduate Diploma in Diabetology (PGDD), MD - Diabetology'
#  'MBBS, M.D. (Psychiatry)'
#  'MBBS, MBBS, MD - General Medicine, MD - Community Medicine, MD - Medicine'
#  'BDS, Certificate in Dental Implants, Certificate in Dental Implants'
#  'Diploma in Cardiology, MBBS, MD - General Medicine, PG in Diabetology'
#  'MBBS, MRCGP, Diploma in Diabetes'
#  'DHMS, DHMS (Diploma in Homeopathic Medicine and Surgery)'
#  'MBBS, MS - ENT, Specialized Training in Otology'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, DLO'
#  'MBBS, MS - General Surgery, MCh - Plastic Surgery'
#  'MBBS, MD - Dermatology, DDV, DNB' 'MBBS, Diploma in Acupuncture'
#  'MBBS, Post Graduate Diploma in Diabetology (PGDD), Diploma in Family Medicine (DFM)'
#  'MRCS (UK), MBBS, MS - Otorhinolaryngology'
#  'MS - Otorhinolaryngology, DNB - ENT'
#  'MBBS, Graduate Diploma in Family Medicine, Singapore'
#  'BDS, Certification in Full Mouth Rehabilitation'
#  'MRCP (UK), Diploma in Dermatology, MBBS' 'MBBS, DDVL, MD - Skin & VD'
#  'BDS, Diploma in Laser Dentistry'
#  'DM - Pulmonary Medicine, MBBS, DM - Critical Care Medicine'
#  'BHMS, Diploma in Dermatology (Alt)'
#  'BDS, Certificate in Dental Implantology'
#  'MBBS, MS - General Surgery, Fellow of Academy of General Education (FAGE), Diploma in Laparoscopy'
#  'MBBS, MD - Skin,VD & Leprosy, Fellow of the American Academy of Dermatology (FAAD), DNB - Dermatology & Venereology'
#  'BHMS, PGDPC (Post Graduation Diploma In Psychological Counselling), Post Graduate Diploma in Emergency Services (PGDEMS)'
#  'BDS, MDS - Oral Pathology & Bacteriology'
#  'MDS - Orthodontics, BDS, MOrth' 'BAMS, DNHE'
#  'MBBS, MD - Tuberculosis & Respiratory Diseases / Pulmonary Medicine'
#  'MBBS, Post Graduate Diploma in Family Medicine (PGDFM)'
#  'MD - Physician, FDIAB, Post Graduate Diploma in Diabetology (PGDD)'
#  'MBBS, FCCP, CCEBDM' 'MS - Otorhinolaryngology, MBBS, DNB - ENT'
#  'MBBS, DM - Cardiology, MD - Medicine'
#  'MD - General Medicine, MBBS, DM - Cardiology'
#  'MDS - Prosthodontist And Crown Bridge, Certificate of Oral Implantology, BDS'
#  'MBBS, MD - Rheumatology'
#  'MD - Physician, PGDHSc, Diploma in Diabetology, Postgraduate Diploma Clinical Cardiology (PGDCC), Fellowship in Diabetology(Johns Hopkins University School of Medicine, USA)'
#  'MS - ENT, DNB - ENT, MBBS, MRCS (UK), MNAMS (Membership of the National Academy)'
#  'BDS, Fellowship in Oral implantlogy, Certificate of Oral Implantology'
#  'BAMS, D-Pharm' 'MBBS, MD - Medicine, Fellowship in Diabetes Management'
#  'BAMS, Diploma in Cosmetology, Diploma in Health Administration'
#  'MS - General Surgery, MBBS'
#  'BAMS, M.S. (Ayurved) Stri Roga & Prasuti Tantra'
#  'MBBS, DNB - Neurology, DNB - General Medicine' 'MBBS, DDVL, DDV'
#  'BHMS, Post Graduate Diploma in Emergency Medical Services, DHMS (Diploma in Homeopathic Medicine and Surgery)'
#  'Certification in Aesthetic Dentistry, MDS - Orthodontics, BDS'
#  'DPM (Psychiatry), MBBS' 'MBBS, MD - Dermatology, DDVL'
#  'BDS, MDS - Orthodontics, Certificate of Oral Implantology'
#  'MD - Acupuncture, PG Diploma In Clinical Cosmetology (PGDCC), BDS'
#  'MBBS, PGDHA'
#  'BDS, MDS - Prosthodontist And Crown Bridge, Certificate of Oral Implantology'
#  'MBBS, MRCOG(UK)'
#  'MD - Medicine, Post Graduate Diploma in Diabetology (PGDD), MBBS, FRCP - Internal Medicine'
#  'MDS - Periodontics' 'MBBS, MS - General Surgery, FAIS, FIAGES'
#  'MBBS, MD - Dermatology , Venereology & Leprosy, DNB - Dermatology, Venereology & Leprosy'
#  'BAMS, Doctor of Medicine' 'MBBS, MD / MS - Obstetrics & Gynaecology']

# %%
#let us find the maximum and minimum number of qualifications of a dotctor in the training and testing datase
# Train set
dat_train = ds_train.Qualification.apply(lambda x: len(x.split(',')))
print("Maximum qualifications of a doctor in the Train dataset is {}\n".format(dat_train.max()))
print("And the qualifications is --> {}\n\n".format(ds_train.Qualification[dat_train.idxmax()]))
print("Minimum qualification of a doctor in the Train dataset is {}\n".format(dat_train.min()))
print("And the qualifications is --> {}\n\n".format(ds_train.Qualification[dat_train.idxmin()]))

# Test set
dat_test = ds_test.Qualification.apply(lambda x: len(x.split(',')))
print("Maximum qualifications of a doctor in the Test dataset is {}\n".format(dat_test.max()))
print("And the qualifications is --> {}\n\n".format(ds_test.Qualification[dat_test.idxmax()]))
print("Minimum qualification of a doctor in the Test dataset is {}\n".format(dat_test.min()))
print("And the qualifications is --> {}".format(ds_test.Qualification[dat_test.idxmin()]))
# Out:
# Maximum qualifications of a doctor in the Train dataset is 10
#
# And the qualifications is --> Fellowship in Oral implantlogy, Certified Advance Course In Endodontics, Certified in Orthodontics, Certification in Full Mouth Rehabilitation, Certified BPS Dentist, Certificate in Cosmetic Dentistry, Professional Implantology Training Course (PITC), Fellowship in Advanced Endoscopic Sinus Surgery, Degree in Dental Implant, Fellowship in Lasers & Cosmetology
#
#
# Minimum qualification of a doctor in the Train dataset is 1
#
# And the qualifications is --> BAMS
#
#
# Maximum qualifications of a doctor in the Test dataset is 17
#
# And the qualifications is --> BDS, PG Diploma in Conservative, Endodontics and Aesthetic Dentistry, Fellowship In Clinical Cosmetology, PG Diploma In Clinical Cosmetology (PGDCC), MBA - Hospital Management, Diploma in Cosmetic Dentistry, Fellow of Academy of General Education (FAGE), Advanced Retreatment Course in RCT, Advanced Endotontic Course On Root Canal, Certified Course in Oral Surgery, MIDA, Certification in Prosthodontics & Periodontology, Certified Advanced Course in Wisdom Tooth Extraction, Certificate in Cosmetic Dentistry, Fellowship in Aesthetic Dentistry (FAD), Post Graduate Certificate in Endodontics (PGCE)
#
#
# Minimum qualification of a doctor in the Test dataset is 1
#
# And the qualifications is --> MBBS

# %%
#Training dataset
#Since our training dataset contains the max number of qualifications as 10,we split them into parts 
ds_train['Qual_1'] = ds_train['Qualification'].str.split(',').str[0]
ds_train['Qual_2'] = ds_train['Qualification'].str.split(',').str[1]
ds_train['Qual_3'] = ds_train['Qualification'].str.split(',').str[2]
ds_train['Qual_4'] = ds_train['Qualification'].str.split(',').str[3]
ds_train['Qual_5'] = ds_train['Qualification'].str.split(',').str[4]
ds_train['Qual_6'] = ds_train['Qualification'].str.split(',').str[5]
ds_train['Qual_7'] = ds_train['Qualification'].str.split(',').str[6]
ds_train['Qual_8'] = ds_train['Qualification'].str.split(',').str[7]
ds_train['Qual_9'] = ds_train['Qualification'].str.split(',').str[8]
ds_train['Qual_10'] = ds_train['Qualification'].str.split(',').str[9]

#while handling this missing values will occur and we replace them with NIL
ds_train['Qual_1'].fillna("NIL",inplace = True)
ds_train['Qual_2'].fillna("NIL",inplace = True)
ds_train['Qual_3'].fillna("NIL",inplace = True)
ds_train['Qual_4'].fillna("NIL",inplace = True)
ds_train['Qual_5'].fillna("NIL",inplace = True)
ds_train['Qual_6'].fillna("NIL",inplace = True)
ds_train['Qual_7'].fillna("NIL",inplace = True)
ds_train['Qual_8'].fillna("NIL",inplace = True)
ds_train['Qual_9'].fillna("NIL",inplace = True)
ds_train['Qual_10'].fillna("NIL",inplace = True)

# %%
ds_train
# Out:
#                        Qualification  Experience Rating  \
# 0              BHMS, MD - Homeopathy          24   100%
# 1       BAMS, MD - Ayurveda Medicine          12    98%
# 2     MBBS, MS - Otorhinolaryngology           9     0%
# 3                BSc - Zoology, BAMS          12     0%
# 4                               BAMS          20   100%
# ...                              ...         ...    ...
# 5956                  MBBS, MS - ENT          19    98%
# 5957                            MBBS          33     0%
# 5958                            MBBS          41    97%
# 5959     MBBS, MD - General Medicine          15    90%
# 5960         BDS, MDS - Orthodontics          17   100%
#
#                        Place           Profile  \
# 0                   Kakkanad         Homeopath
# 1                 Whitefield          Ayurveda
# 2            Mathikere - BEL    ENT Specialist
# 3          Bannerghatta Road          Ayurveda
# 4               Keelkattalai          Ayurveda
# ...                      ...               ...
# 5956            Basavanagudi    ENT Specialist
# 5957            Nungambakkam  General Medicine
# 5958  Greater Kailash Part 2  General Medicine
# 5959          Vileparle West  General Medicine
# 5960               Pitampura           Dentist
#
#                                      Miscellaneous_Info  Fees        City  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100   Ernakulam
# 1                 98% 76 Feedback Whitefield, Bangalore   350   Bangalore
# 2                                         Others,Others   300   Bangalore
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250   Bangalore
# 4                 100% 4 Feedback Keelkattalai, Chennai   250     Chennai
# ...                                                 ...   ...         ...
# 5956            98% 45 Feedback Basavanagudi, Bangalore   300   Bangalore
# 5957                                      Others,Others   100     Chennai
# 5958      97% 11 Feedback Greater Kailash Part 2, Delhi   600       Delhi
# 5959  General Medical Consultation Viral Fever Treat...   100      Mumbai
# 5960  Acrylic Partial Denture Crowns and Bridges Fix...   200       Delhi
#
#              Qual_1                     Qual_2 Qual_3 Qual_4 Qual_5 Qual_6  \
# 0              BHMS            MD - Homeopathy    NIL    NIL    NIL    NIL
# 1              BAMS     MD - Ayurveda Medicine    NIL    NIL    NIL    NIL
# 2              MBBS   MS - Otorhinolaryngology    NIL    NIL    NIL    NIL
# 3     BSc - Zoology                       BAMS    NIL    NIL    NIL    NIL
# 4              BAMS                        NIL    NIL    NIL    NIL    NIL
# ...             ...                        ...    ...    ...    ...    ...
# 5956           MBBS                   MS - ENT    NIL    NIL    NIL    NIL
# 5957           MBBS                        NIL    NIL    NIL    NIL    NIL
# 5958           MBBS                        NIL    NIL    NIL    NIL    NIL
# 5959           MBBS      MD - General Medicine    NIL    NIL    NIL    NIL
# 5960            BDS         MDS - Orthodontics    NIL    NIL    NIL    NIL
#
#      Qual_7 Qual_8 Qual_9 Qual_10
# 0       NIL    NIL    NIL     NIL
# 1       NIL    NIL    NIL     NIL
# 2       NIL    NIL    NIL     NIL
# 3       NIL    NIL    NIL     NIL
# 4       NIL    NIL    NIL     NIL
# ...     ...    ...    ...     ...
# 5956    NIL    NIL    NIL     NIL
# 5957    NIL    NIL    NIL     NIL
# 5958    NIL    NIL    NIL     NIL
# 5959    NIL    NIL    NIL     NIL
# 5960    NIL    NIL    NIL     NIL
#
# [5961 rows x 18 columns]

# %% [markdown]
# 1. for i in range(0,5961):
# 2. if ds_train.Qualification[i]==ds_train.Qualification[dat_train.idxmax()]:
# 3. ds_train[i]
#
# For this code i got key error in the index 2035.

# %%
#let me check the qualification status of 2035 th index
ds_train['Qualification'].iloc[2035]
# Out:
# 'Fellowship in Oral implantlogy, Certified Advance Course In Endodontics, Certified in Orthodontics, Certification in Full Mouth Rehabilitation, Certified BPS Dentist, Certificate in Cosmetic Dentistry, Professional Implantology Training Course (PITC), Fellowship in Advanced Endoscopic Sinus Surgery, Degree in Dental Implant, Fellowship in Lasers & Cosmetology'

# %%
#let us find whether our splitting is done as expected
ds_train.iloc[2035:2040,:]
# Out:
#                                           Qualification  Experience Rating  \
# 2035  Fellowship in Oral implantlogy, Certified Adva...          22    97%
# 2036                                               BAMS          10   100%
# 2037                                               BAMS           7     0%
# 2038                                           BDS, MDS          22    97%
# 2039                                               BHMS          27     0%
#
#                  Place    Profile  \
# 2035       Ashok Nagar    Dentist
# 2036       Malleswaram   Ayurveda
# 2037  JP Nagar 1 Phase   Ayurveda
# 2038    Rajouri Garden    Dentist
# 2039       Mehdipatnam  Homeopath
#
#                                      Miscellaneous_Info  Fees        City  \
# 2035  RCT - Root Canal Treatment Cosmetic/ Aesthetic...   300     Chennai
# 2036            100% 10 Feedback Malleswaram, Bangalore   100   Bangalore
# 2037                         Pizhichil Sirodhara Vasthi   300   Bangalore
# 2038              97% 19 Feedback Rajouri Garden, Delhi   200       Delhi
# 2039  Wrinkle Treatment Allergy Treatment Viral Feve...   300   Hyderabad
#
#                               Qual_1  \
# 2035  Fellowship in Oral implantlogy
# 2036                            BAMS
# 2037                            BAMS
# 2038                             BDS
# 2039                            BHMS
#
#                                         Qual_2                      Qual_3  \
# 2035   Certified Advance Course In Endodontics   Certified in Orthodontics
# 2036                                       NIL                         NIL
# 2037                                       NIL                         NIL
# 2038                                       MDS                         NIL
# 2039                                       NIL                         NIL
#
#                                            Qual_4                  Qual_5  \
# 2035   Certification in Full Mouth Rehabilitation   Certified BPS Dentist
# 2036                                          NIL                     NIL
# 2037                                          NIL                     NIL
# 2038                                          NIL                     NIL
# 2039                                          NIL                     NIL
#
#                                   Qual_6  \
# 2035   Certificate in Cosmetic Dentistry
# 2036                                 NIL
# 2037                                 NIL
# 2038                                 NIL
# 2039                                 NIL
#
#                                                  Qual_7  \
# 2035   Professional Implantology Training Course (PITC)
# 2036                                                NIL
# 2037                                                NIL
# 2038                                                NIL
# 2039                                                NIL
#
#                                                 Qual_8  \
# 2035   Fellowship in Advanced Endoscopic Sinus Surgery
# 2036                                               NIL
# 2037                                               NIL
# 2038                                               NIL
# 2039                                               NIL
#
#                          Qual_9                              Qual_10
# 2035   Degree in Dental Implant   Fellowship in Lasers & Cosmetology
# 2036                        NIL                                  NIL
# 2037                        NIL                                  NIL
# 2038                        NIL                                  NIL
# 2039                        NIL                                  NIL

# %%
#For testing dataset we have to do the same steps
#Since our testing dataset contains the max number of qualifications as 17,we split them into parts 
ds_test['Qual_1'] = ds_test['Qualification'].str.split(',').str[0]
ds_test['Qual_2'] = ds_test['Qualification'].str.split(',').str[1]
ds_test['Qual_3'] = ds_test['Qualification'].str.split(',').str[2]
ds_test['Qual_4'] = ds_test['Qualification'].str.split(',').str[3]
ds_test['Qual_5'] = ds_test['Qualification'].str.split(',').str[4]
ds_test['Qual_6'] = ds_test['Qualification'].str.split(',').str[5]
ds_test['Qual_7'] = ds_test['Qualification'].str.split(',').str[6]
ds_test['Qual_8'] = ds_test['Qualification'].str.split(',').str[7]
ds_test['Qual_9'] = ds_test['Qualification'].str.split(',').str[8]
ds_test['Qual_10'] = ds_test['Qualification'].str.split(',').str[9]
ds_test['Qual_11'] = ds_test['Qualification'].str.split(',').str[10]
ds_test['Qual_12'] = ds_test['Qualification'].str.split(',').str[11]
ds_test['Qual_13'] = ds_test['Qualification'].str.split(',').str[12]
ds_test['Qual_14'] = ds_test['Qualification'].str.split(',').str[13]
ds_test['Qual_15'] = ds_test['Qualification'].str.split(',').str[14]
ds_test['Qual_16'] = ds_test['Qualification'].str.split(',').str[15]
ds_test['Qual_17'] = ds_test['Qualification'].str.split(',').str[16]


#while handling this missing values will occur and we replace them with NIL
ds_test['Qual_1'].fillna("NIL",inplace = True)
ds_test['Qual_2'].fillna("NIL",inplace = True)
ds_test['Qual_3'].fillna("NIL",inplace = True)
ds_test['Qual_4'].fillna("NIL",inplace = True)
ds_test['Qual_5'].fillna("NIL",inplace = True)
ds_test['Qual_6'].fillna("NIL",inplace = True)
ds_test['Qual_7'].fillna("NIL",inplace = True)
ds_test['Qual_8'].fillna("NIL",inplace = True)
ds_test['Qual_9'].fillna("NIL",inplace = True)
ds_test['Qual_10'].fillna("NIL",inplace = True)
ds_test['Qual_11'].fillna("NIL",inplace = True)
ds_test['Qual_12'].fillna("NIL",inplace = True)
ds_test['Qual_13'].fillna("NIL",inplace = True)
ds_test['Qual_14'].fillna("NIL",inplace = True)
ds_test['Qual_15'].fillna("NIL",inplace = True)
ds_test['Qual_16'].fillna("NIL",inplace = True)
ds_test['Qual_17'].fillna("NIL",inplace = True)

ds_test
# Out:
#                                         Qualification  Experience Rating  \
# 0                                                MBBS          35     0%
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31     0%
# 2                                          MBBS, DDVL          40    70%
# 3                                                BAMS           0     0%
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16   100%
# ...                                               ...         ...    ...
# 1982                         BAMS, Doctor of Medicine          10     0%
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4     0%
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9     0%
# 1985                                              BDS          12    98%
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8     0%
#
#                  Place           Profile  \
# 0       Ghatkopar East  General Medicine
# 1     West Marredpally    ENT Specialist
# 2             KK Nagar    Dermatologists
# 3      New Ashok Nagar          Ayurveda
# 4       Kanakpura Road           Dentist
# ...                ...               ...
# 1982      Basavanagudi          Ayurveda
# 1983           Choolai    Dermatologists
# 1984             Porur  General Medicine
# 1985           Arekere           Dentist
# 1986      Pallikaranai    Dermatologists
#
#                                      Miscellaneous_Info        City  \
# 0                                         Others,Others      Mumbai
# 1                                         Others,Others   Hyderabad
# 2                      70% 4 Feedback KK Nagar, Chennai     Chennai
# 3                                         Others,Others       Delhi
# 4     General Dentistry Conservative Dentistry Cosme...   Bangalore
# ...                                                 ...         ...
# 1982                                      Others,Others   Bangalore
# 1983                                      Others,Others     Chennai
# 1984                                      Others,Others     Chennai
# 1985  RCT - Root Canal Treatment Root Canal Treatmen...   Bangalore
# 1986              1 Feedback Pallikaranai, Chennai ₹500     Chennai
#
#                  Qual_1                                       Qual_2  \
# 0                  MBBS                                          NIL
# 1                  MBBS         Diploma in Otorhinolaryngology (DLO)
# 2                  MBBS                                         DDVL
# 3                  BAMS                                          NIL
# 4                   BDS   MDS - Conservative Dentistry & Endodontics
# ...                 ...                                          ...
# 1982               BAMS                           Doctor of Medicine
# 1983  MD - Dermatology                         Venereology & Leprosy
# 1984               MBBS           MD / MS - Obstetrics & Gynaecology
# 1985                BDS                                          NIL
# 1986               MBBS                            MD - Dermatology
#
#                       Qual_3  ... Qual_8 Qual_9 Qual_10 Qual_11 Qual_12  \
# 0                        NIL  ...    NIL    NIL     NIL     NIL     NIL
# 1                        NIL  ...    NIL    NIL     NIL     NIL     NIL
# 2                        NIL  ...    NIL    NIL     NIL     NIL     NIL
# 3                        NIL  ...    NIL    NIL     NIL     NIL     NIL
# 4                        NIL  ...    NIL    NIL     NIL     NIL     NIL
# ...                      ...  ...    ...    ...     ...     ...     ...
# 1982                     NIL  ...    NIL    NIL     NIL     NIL     NIL
# 1983                    MBBS  ...    NIL    NIL     NIL     NIL     NIL
# 1984                     NIL  ...    NIL    NIL     NIL     NIL     NIL
# 1985                     NIL  ...    NIL    NIL     NIL     NIL     NIL
# 1986   Venereology & Leprosy  ...    NIL    NIL     NIL     NIL     NIL
#
#      Qual_13 Qual_14 Qual_15 Qual_16 Qual_17
# 0        NIL     NIL     NIL     NIL     NIL
# 1        NIL     NIL     NIL     NIL     NIL
# 2        NIL     NIL     NIL     NIL     NIL
# 3        NIL     NIL     NIL     NIL     NIL
# 4        NIL     NIL     NIL     NIL     NIL
# ...      ...     ...     ...     ...     ...
# 1982     NIL     NIL     NIL     NIL     NIL
# 1983     NIL     NIL     NIL     NIL     NIL
# 1984     NIL     NIL     NIL     NIL     NIL
# 1985     NIL     NIL     NIL     NIL     NIL
# 1986     NIL     NIL     NIL     NIL     NIL
#
# [1987 rows x 24 columns]

# %%
ds_test.iloc[1285:1295,:]
# Out:
#                                           Qualification  Experience Rating  \
# 1285            BHMS, Certificate in Child Health (CCH)          11     0%
# 1286                BAMS, Diploma in Emergency Medicine           9     0%
# 1287  BDS, PG Diploma in Conservative, Endodontics a...           4   100%
# 1288  FAMS - Fellowship of the Academy Medicine, MBB...          28    60%
# 1289                                               BAMS           7     0%
# 1290                                               BAMS          25    92%
# 1291  BDS, MDS - Conservative Dentistry & Endodontic...          21     0%
# 1292                                               BHMS           4     0%
# 1293  BHMS, MD - Homeopathy, MS - Counselling and Ps...          27     0%
# 1294            BAMS, Fellowship in Medical Cosmetology          15    60%
#
#                  Place         Profile  \
# 1285             Kapra       Homeopath
# 1286        Yousufguda        Ayurveda
# 1287   New Ashok Nagar         Dentist
# 1288      AS Rao Nagar  ENT Specialist
# 1289      Andheri East        Ayurveda
# 1290  Ramamurthy Nagar        Ayurveda
# 1291      Mugalivakkam         Dentist
# 1292          Shahdara       Homeopath
# 1293     Goregaon West       Homeopath
# 1294            Dwarka        Ayurveda
#
#                                      Miscellaneous_Info        City  \
# 1285                                      Others,Others   Hyderabad
# 1286                                      Others,Others   Hyderabad
# 1287  Dental Crowns Dental Fillings Dental Implant F...       Delhi
# 1288             60% 1 Feedback AS Rao Nagar, Hyderabad   Hyderabad
# 1289                                      Others,Others      Mumbai
# 1290        92% 12 Feedback Ramamurthy Nagar, Bangalore   Bangalore
# 1291            Mugalivakkam, Chennai ₹300 Visits Today     Chennai
# 1292                                      Others,Others       Delhi
# 1293                                      Others,Others      Mumbai
# 1294                       60% 1 Feedback Dwarka, Delhi       Delhi
#
#                                          Qual_1  \
# 1285                                       BHMS
# 1286                                       BAMS
# 1287                                        BDS
# 1288  FAMS - Fellowship of the Academy Medicine
# 1289                                       BAMS
# 1290                                       BAMS
# 1291                                        BDS
# 1292                                       BHMS
# 1293                                       BHMS
# 1294                                       BAMS
#
#                                            Qual_2  \
# 1285            Certificate in Child Health (CCH)
# 1286                Diploma in Emergency Medicine
# 1287                   PG Diploma in Conservative
# 1288                                         MBBS
# 1289                                          NIL
# 1290                                          NIL
# 1291   MDS - Conservative Dentistry & Endodontics
# 1292                                          NIL
# 1293                              MD - Homeopathy
# 1294            Fellowship in Medical Cosmetology
#
#                                     Qual_3  ...  \
# 1285                                   NIL  ...
# 1286                                   NIL  ...
# 1287   Endodontics and Aesthetic Dentistry  ...
# 1288                              MS - ENT  ...
# 1289                                   NIL  ...
# 1290                                   NIL  ...
# 1291                     MD - Dental Laser  ...
# 1292                                   NIL  ...
# 1293    MS - Counselling and Psychotherapy  ...
# 1294                                   NIL  ...
#
#                                               Qual_8  \
# 1285                                             NIL
# 1286                                             NIL
# 1287   Fellow of Academy of General Education (FAGE)
# 1288                        Cochlear Implant Surgery
# 1289                                             NIL
# 1290                                             NIL
# 1291                                             NIL
# 1292                                             NIL
# 1293                                             NIL
# 1294                                             NIL
#
#                                                  Qual_9  \
# 1285                                                NIL
# 1286                                                NIL
# 1287                 Advanced Retreatment Course in RCT
# 1288   Advance Course on Diagnosis of Allergy and Im...
# 1289                                                NIL
# 1290                                                NIL
# 1291                                                NIL
# 1292                                                NIL
# 1293                                                NIL
# 1294                                                NIL
#
#                                         Qual_10  \
# 1285                                        NIL
# 1286                                        NIL
# 1287   Advanced Endotontic Course On Root Canal
# 1288                                        NIL
# 1289                                        NIL
# 1290                                        NIL
# 1291                                        NIL
# 1292                                        NIL
# 1293                                        NIL
# 1294                                        NIL
#
#                                 Qual_11 Qual_12  \
# 1285                                NIL     NIL
# 1286                                NIL     NIL
# 1287   Certified Course in Oral Surgery    MIDA
# 1288                                NIL     NIL
# 1289                                NIL     NIL
# 1290                                NIL     NIL
# 1291                                NIL     NIL
# 1292                                NIL     NIL
# 1293                                NIL     NIL
# 1294                                NIL     NIL
#
#                                                 Qual_13  \
# 1285                                                NIL
# 1286                                                NIL
# 1287   Certification in Prosthodontics & Periodontology
# 1288                                                NIL
# 1289                                                NIL
# 1290                                                NIL
# 1291                                                NIL
# 1292                                                NIL
# 1293                                                NIL
# 1294                                                NIL
#
#                                                 Qual_14  \
# 1285                                                NIL
# 1286                                                NIL
# 1287   Certified Advanced Course in Wisdom Tooth Ext...
# 1288                                                NIL
# 1289                                                NIL
# 1290                                                NIL
# 1291                                                NIL
# 1292                                                NIL
# 1293                                                NIL
# 1294                                                NIL
#
#                                  Qual_15  \
# 1285                                 NIL
# 1286                                 NIL
# 1287   Certificate in Cosmetic Dentistry
# 1288                                 NIL
# 1289                                 NIL
# 1290                                 NIL
# 1291                                 NIL
# 1292                                 NIL
# 1293                                 NIL
# 1294                                 NIL
#
#                                        Qual_16  \
# 1285                                       NIL
# 1286                                       NIL
# 1287   Fellowship in Aesthetic Dentistry (FAD)
# 1288                                       NIL
# 1289                                       NIL
# 1290                                       NIL
# 1291                                       NIL
# 1292                                       NIL
# 1293                                       NIL
# 1294                                       NIL
#
#                                                Qual_17
# 1285                                               NIL
# 1286                                               NIL
# 1287   Post Graduate Certificate in Endodontics (PGCE)
# 1288                                               NIL
# 1289                                               NIL
# 1290                                               NIL
# 1291                                               NIL
# 1292                                               NIL
# 1293                                               NIL
# 1294                                               NIL
#
# [10 rows x 24 columns]

# %%
#lets create a new column for the count of qualifications in both training and testing dataset
ds_train['Qual_count'] = ds_train.Qualification.apply(lambda x: len(x.split(',')))
ds_test['Qual_count'] = ds_test.Qualification.apply(lambda x: len(x.split(',')))

# %%
#lets convert rating column into integer type
ds_train['Rating'] = ds_train['Rating'].str.slice(stop=-1).astype(int)         #training dataset
ds_test['Rating'] = ds_test['Rating'].str.slice(stop=-1).astype(int)           #testing dataset

# %%
#lets check the training dataset
ds_train
# Out:
#                        Qualification  Experience  Rating  \
# 0              BHMS, MD - Homeopathy          24     100
# 1       BAMS, MD - Ayurveda Medicine          12      98
# 2     MBBS, MS - Otorhinolaryngology           9       0
# 3                BSc - Zoology, BAMS          12       0
# 4                               BAMS          20     100
# ...                              ...         ...     ...
# 5956                  MBBS, MS - ENT          19      98
# 5957                            MBBS          33       0
# 5958                            MBBS          41      97
# 5959     MBBS, MD - General Medicine          15      90
# 5960         BDS, MDS - Orthodontics          17     100
#
#                        Place           Profile  \
# 0                   Kakkanad         Homeopath
# 1                 Whitefield          Ayurveda
# 2            Mathikere - BEL    ENT Specialist
# 3          Bannerghatta Road          Ayurveda
# 4               Keelkattalai          Ayurveda
# ...                      ...               ...
# 5956            Basavanagudi    ENT Specialist
# 5957            Nungambakkam  General Medicine
# 5958  Greater Kailash Part 2  General Medicine
# 5959          Vileparle West  General Medicine
# 5960               Pitampura           Dentist
#
#                                      Miscellaneous_Info  Fees        City  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100   Ernakulam
# 1                 98% 76 Feedback Whitefield, Bangalore   350   Bangalore
# 2                                         Others,Others   300   Bangalore
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250   Bangalore
# 4                 100% 4 Feedback Keelkattalai, Chennai   250     Chennai
# ...                                                 ...   ...         ...
# 5956            98% 45 Feedback Basavanagudi, Bangalore   300   Bangalore
# 5957                                      Others,Others   100     Chennai
# 5958      97% 11 Feedback Greater Kailash Part 2, Delhi   600       Delhi
# 5959  General Medical Consultation Viral Fever Treat...   100      Mumbai
# 5960  Acrylic Partial Denture Crowns and Bridges Fix...   200       Delhi
#
#              Qual_1                     Qual_2 Qual_3 Qual_4 Qual_5 Qual_6  \
# 0              BHMS            MD - Homeopathy    NIL    NIL    NIL    NIL
# 1              BAMS     MD - Ayurveda Medicine    NIL    NIL    NIL    NIL
# 2              MBBS   MS - Otorhinolaryngology    NIL    NIL    NIL    NIL
# 3     BSc - Zoology                       BAMS    NIL    NIL    NIL    NIL
# 4              BAMS                        NIL    NIL    NIL    NIL    NIL
# ...             ...                        ...    ...    ...    ...    ...
# 5956           MBBS                   MS - ENT    NIL    NIL    NIL    NIL
# 5957           MBBS                        NIL    NIL    NIL    NIL    NIL
# 5958           MBBS                        NIL    NIL    NIL    NIL    NIL
# 5959           MBBS      MD - General Medicine    NIL    NIL    NIL    NIL
# 5960            BDS         MDS - Orthodontics    NIL    NIL    NIL    NIL
#
#      Qual_7 Qual_8 Qual_9 Qual_10  Qual_count
# 0       NIL    NIL    NIL     NIL           2
# 1       NIL    NIL    NIL     NIL           2
# 2       NIL    NIL    NIL     NIL           2
# 3       NIL    NIL    NIL     NIL           2
# 4       NIL    NIL    NIL     NIL           1
# ...     ...    ...    ...     ...         ...
# 5956    NIL    NIL    NIL     NIL           2
# 5957    NIL    NIL    NIL     NIL           1
# 5958    NIL    NIL    NIL     NIL           1
# 5959    NIL    NIL    NIL     NIL           2
# 5960    NIL    NIL    NIL     NIL           2
#
# [5961 rows x 19 columns]

# %%
#we can drop the Qualification and Miscellaneous_Info columns
ds_train.drop(columns=['Qualification','Miscellaneous_Info'],axis=1,inplace=True)         #training dataset
ds_test.drop(columns=['Qualification','Miscellaneous_Info'],axis=1,inplace=True)          #testing dataset

# %%
ds_train
# Out:
#       Experience  Rating                   Place           Profile  Fees  \
# 0             24     100                Kakkanad         Homeopath   100
# 1             12      98              Whitefield          Ayurveda   350
# 2              9       0         Mathikere - BEL    ENT Specialist   300
# 3             12       0       Bannerghatta Road          Ayurveda   250
# 4             20     100            Keelkattalai          Ayurveda   250
# ...          ...     ...                     ...               ...   ...
# 5956          19      98            Basavanagudi    ENT Specialist   300
# 5957          33       0            Nungambakkam  General Medicine   100
# 5958          41      97  Greater Kailash Part 2  General Medicine   600
# 5959          15      90          Vileparle West  General Medicine   100
# 5960          17     100               Pitampura           Dentist   200
#
#             City         Qual_1                     Qual_2 Qual_3 Qual_4  \
# 0      Ernakulam           BHMS            MD - Homeopathy    NIL    NIL
# 1      Bangalore           BAMS     MD - Ayurveda Medicine    NIL    NIL
# 2      Bangalore           MBBS   MS - Otorhinolaryngology    NIL    NIL
# 3      Bangalore  BSc - Zoology                       BAMS    NIL    NIL
# 4        Chennai           BAMS                        NIL    NIL    NIL
# ...          ...            ...                        ...    ...    ...
# 5956   Bangalore           MBBS                   MS - ENT    NIL    NIL
# 5957     Chennai           MBBS                        NIL    NIL    NIL
# 5958       Delhi           MBBS                        NIL    NIL    NIL
# 5959      Mumbai           MBBS      MD - General Medicine    NIL    NIL
# 5960       Delhi            BDS         MDS - Orthodontics    NIL    NIL
#
#      Qual_5 Qual_6 Qual_7 Qual_8 Qual_9 Qual_10  Qual_count
# 0       NIL    NIL    NIL    NIL    NIL     NIL           2
# 1       NIL    NIL    NIL    NIL    NIL     NIL           2
# 2       NIL    NIL    NIL    NIL    NIL     NIL           2
# 3       NIL    NIL    NIL    NIL    NIL     NIL           2
# 4       NIL    NIL    NIL    NIL    NIL     NIL           1
# ...     ...    ...    ...    ...    ...     ...         ...
# 5956    NIL    NIL    NIL    NIL    NIL     NIL           2
# 5957    NIL    NIL    NIL    NIL    NIL     NIL           1
# 5958    NIL    NIL    NIL    NIL    NIL     NIL           1
# 5959    NIL    NIL    NIL    NIL    NIL     NIL           2
# 5960    NIL    NIL    NIL    NIL    NIL     NIL           2
#
# [5961 rows x 17 columns]

# %%
#lets see the value of unique cities 
print(ds_train['City'].value_counts())                 #training dataset
print(ds_test['City'].value_counts())                 #testing dataset
# Out:
#  Bangalore             1258
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# Others                   25
# e                         1
# Name: City, dtype: int64
#  Bangalore             420
#  Delhi                 417
#  Mumbai                389
#  Hyderabad             333
#  Chennai               287
#  Coimbatore             70
#  Ernakulam              48
#  Thiruvananthapuram     17
# Others                   6
# Name: City, dtype: int64

# %% [markdown]
# There is a city name e in the training dataset, which may be mistyped.lets replace it by others.

# %%
ds_train['City'].replace('e','Others',inplace=True)

# %%
#lets see the counts of cities in the training dataset
plt.figure(figsize=(10,10))
sns.countplot(x='City',data=ds_train)
plt.show()
ds_train['City'].value_counts()
# Out:
#  Bangalore             1258
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# Others                   26
# Name: City, dtype: int64

# %% [markdown]
# Most of the datas recorded are by the doctors of Bangalore.

# %%
#lets see the profiles of doctors in training and testing datatset
plt.figure(figsize=(10,10))
sns.countplot(x='Profile',data=ds_train)
plt.show()
print(ds_train['Profile'].value_counts())                     #training dataset
print('\n')
plt.figure(figsize=(10,10))
sns.countplot(x='Profile',data=ds_test)
plt.show()
print(ds_test['Profile'].value_counts())                     #testing dataset
# Out:
# Dentist             1397
# General Medicine    1173
# Dermatologists      1034
# Homeopath            843
# Ayurveda             786
# ENT Specialist       728
# Name: Profile, dtype: int64
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %% [markdown]
# In training dataset,highest count is for profile Dentist and in testing dataset, highest count is for profile Generala Medicine.

# %%
#lets find the maximum fee charged by a doctor
print('Maximum fee charged by a doctor is : ',ds_train['Fees'].max())
#lets find the minimum fee charged by a doctor
print('Minimum fee charged by a doctor is : ',ds_train['Fees'].min())
# Out:
# Maximum fee charged by a doctor is :  950
# Minimum fee charged by a doctor is :  5

# %%
#lets find the details of the doctor charging the max fee
ds_train[ds_train['Fees']==950]
# Out:
#      Experience  Rating  Place           Profile  Fees      City Qual_1  \
# 293          29     100  Adyar  General Medicine   950   Chennai   MBBS
#
#                       Qual_2 Qual_3 Qual_4 Qual_5 Qual_6 Qual_7 Qual_8 Qual_9  \
# 293   MD - Internal Medicine   FRCP    NIL    NIL    NIL    NIL    NIL    NIL
#
#     Qual_10  Qual_count
# 293     NIL           3

# %% [markdown]
# The highest fee is charged by a General Medicine Doctor residing in Chennai city

# %%
#lets find the details of the doctor charging the min fee
ds_train[ds_train['Fees']==5]
# Out:
#       Experience  Rating               Place  Profile  Fees  \
# 1930           6       0  TV Medical College  Dentist     5
#
#                      City Qual_1 Qual_2 Qual_3 Qual_4 Qual_5 Qual_6 Qual_7  \
# 1930   Thiruvananthapuram    BDS    NIL    NIL    NIL    NIL    NIL    NIL
#
#      Qual_8 Qual_9 Qual_10  Qual_count
# 1930    NIL    NIL     NIL           1

# %% [markdown]
# The lowest fee is charged by a Dentist residing in Thiruvananthapuram city.

# %%
#lets find the details of the doctors having rating 100
ds_train[ds_train['Rating']==100]
# Out:
#       Experience  Rating         Place           Profile  Fees         City  \
# 0             24     100      Kakkanad         Homeopath   100    Ernakulam
# 4             20     100  Keelkattalai          Ayurveda   250      Chennai
# 19            19     100    HSR Layout  General Medicine   150    Bangalore
# 20            21     100      Pollachi           Dentist   100   Coimbatore
# 26            25     100    HSR Layout  General Medicine   500    Bangalore
# ...          ...     ...           ...               ...   ...          ...
# 5899          11     100        Jasola           Dentist   100        Delhi
# 5901          12     100    Malkajgiri    Dermatologists   300    Hyderabad
# 5936          34     100       Chembur         Homeopath   100       Mumbai
# 5950           4     100   Konanakunte    Dermatologists   350    Bangalore
# 5960          17     100     Pitampura           Dentist   200        Delhi
#
#                  Qual_1                                  Qual_2  \
# 0                  BHMS                         MD - Homeopathy
# 4                  BAMS                                     NIL
# 19                 MBBS                                     NIL
# 20                  MDS                                     DNB
# 26                 MBBS                             IBCLC (USA)
# ...                 ...                                     ...
# 5899                BDS   MDS - Prosthodontist And Crown Bridge
# 5901               MBBS                       MD - Dermatology
# 5936    MD - Homeopathy                                    LCEH
# 5950  MD - Dermatology                    Venereology & Leprosy
# 5960                BDS                      MDS - Orthodontics
#
#                                              Qual_3  \
# 0                                               NIL
# 4                                               NIL
# 19                                              NIL
# 20                                              BDS
# 26                                              NIL
# ...                                             ...
# 5899                                            NIL
# 5901                          Venereology & Leprosy
# 5936   Diploma in Preventive & Promotive Healthcare
# 5950                                           MBBS
# 5960                                            NIL
#
#                              Qual_4 Qual_5 Qual_6 Qual_7 Qual_8 Qual_9  \
# 0                               NIL    NIL    NIL    NIL    NIL    NIL
# 4                               NIL    NIL    NIL    NIL    NIL    NIL
# 19                              NIL    NIL    NIL    NIL    NIL    NIL
# 20                              NIL    NIL    NIL    NIL    NIL    NIL
# 26                              NIL    NIL    NIL    NIL    NIL    NIL
# ...                             ...    ...    ...    ...    ...    ...
# 5899                            NIL    NIL    NIL    NIL    NIL    NIL
# 5901                            NIL    NIL    NIL    NIL    NIL    NIL
# 5936                            NIL    NIL    NIL    NIL    NIL    NIL
# 5950   Fellowship In Dermatosurgery    NIL    NIL    NIL    NIL    NIL
# 5960                            NIL    NIL    NIL    NIL    NIL    NIL
#
#      Qual_10  Qual_count
# 0        NIL           2
# 4        NIL           1
# 19       NIL           1
# 20       NIL           3
# 26       NIL           2
# ...      ...         ...
# 5899     NIL           2
# 5901     NIL           3
# 5936     NIL           3
# 5950     NIL           4
# 5960     NIL           2
#
# [684 rows x 17 columns]

# %%
#lets find the highest experience years served by a doctor in  training daatset
print('Highest experience by a doctor is : ',ds_train['Experience'].max())
#lets find the lowest experience years served by a doctor
print('Lowest experience by a doctor is : ',ds_train['Experience'].min())
# Out:
# Highest experience by a doctor is :  66
# Lowest experience by a doctor is :  0

# %%
#details of doctor having the highest experience
ds_train[ds_train['Experience']==66]
# Out:
#      Experience  Rating        Place         Profile  Fees      City Qual_1  \
# 372          66       0  Greams Road  ENT Specialist   100   Chennai   MBBS
#
#                                     Qual_2 Qual_3 Qual_4 Qual_5 Qual_6 Qual_7  \
# 372   Diploma in Otorhinolaryngology (DLO)    NIL    NIL    NIL    NIL    NIL
#
#     Qual_8 Qual_9 Qual_10  Qual_count
# 372    NIL    NIL     NIL           2

# %% [markdown]
# The fee charged by the most experienced doctor is 100 residing in the city Chennai.

# %%
#Lets find the maximum fees charged by doctors in various cities
ds_train.groupby('City')['Fees'].max()
# Out:
# City
#  Bangalore             900
#  Chennai               950
#  Coimbatore            700
#  Delhi                 900
#  Ernakulam             600
#  Hyderabad             800
#  Mumbai                920
#  Thiruvananthapuram    500
# Others                 250
# Name: Fees, dtype: int64

# %%
#histogram plot of Fees
plt.figure()
plt.hist(x=ds_train['Fees'],bins=20,range=(0,1000))
plt.show()

# %% [markdown]
# Majority of doctors are charging a fee of 100.

# %%
#histogram plot of Experience
plt.figure()
plt.hist(x=ds_train['Experience'],bins=20,range=(0,70))
plt.show()

# %% [markdown]
# Majority of the doctors are having an experience of 9 years.

# %%
#histogram plot of rating
plt.figure()
plt.hist(x=ds_train['Rating'],bins=50,range=(0,100))
plt.show()

# %% [markdown]
# Majority of the ratings were missing and were imputed as 0. The highest ratings given by actual people is for 100%.

# %%
#lets find the mean fees charged across various cities
plt.figure(figsize=(10,10))
sns.barplot(x='City',y='Fees',data=ds_train)
plt.show()
print(ds_train.groupby('City')['Fees'].mean())
# Out:
# City
#  Bangalore             328.842607
#  Chennai               283.602339
#  Coimbatore            154.298246
#  Delhi                 362.911392
#  Ernakulam             188.431373
#  Hyderabad             307.507886
#  Mumbai                308.292863
#  Thiruvananthapuram    167.267442
# Others                 107.692308
# Name: Fees, dtype: float64

# %% [markdown]
# Among the 8 cities Delhi has the highest mean fees charged by the doctors in that place and Others have the lowest mean.

# %%
#lets find the mean fees charged by doctors of various profiles
plt.figure(figsize=(10,10))
sns.barplot(x='Profile',y='Fees',data=ds_train)
plt.show()
print(ds_train.groupby('Profile')['Fees'].mean())
# Out:
# Profile
# Ayurveda            238.968193
# Dentist             238.199714
# Dermatologists      393.133462
# ENT Specialist      387.321429
# General Medicine    313.908781
# Homeopath           306.499407
# Name: Fees, dtype: float64

# %% [markdown]
# Among the various profiles Dermatologists have the highest mean fees charged and Dentists have the lower mean fees charged.
# There is not much difference between the Dentists and the Ayurveda Doctors in terms of mean fees charged.

# %%
#mean fees of doctors possessing number of qualifications.
plt.figure(figsize=(10,10))
sns.barplot(x='Qual_count',y='Fees',data=ds_train)
plt.show()
print(ds_train.groupby('Qual_count')['Fees'].mean())
# Out:
# Qual_count
# 1     237.524465
# 2     330.705860
# 3     358.412060
# 4     373.540856
# 5     416.309524
# 6     363.043478
# 7     433.333333
# 8     400.000000
# 9     300.000000
# 10    300.000000
# Name: Fees, dtype: float64

# %% [markdown]
# Doctors with 7 qualifications have the highest mean fees.

# %%
#Converting datatypes
#Rating
ds_train['Rating']=ds_train['Rating'].astype('float')
ds_test['Rating']=ds_test['Rating'].astype('float')
#Experience
ds_train['Experience']=ds_train['Experience'].astype('float')
ds_test['Experience']=ds_test['Experience'].astype('float')

# %%
ds_train.dtypes
# Out:
# Experience    float64
# Rating        float64
# Place          object
# Profile        object
# Fees            int64
# City           object
# Qual_1         object
# Qual_2         object
# Qual_3         object
# Qual_4         object
# Qual_5         object
# Qual_6         object
# Qual_7         object
# Qual_8         object
# Qual_9         object
# Qual_10        object
# Qual_count      int64
# dtype: object

# %%
ds_test.dtypes
# Out:
# Experience    float64
# Rating        float64
# Place          object
# Profile        object
# City           object
# Qual_1         object
# Qual_2         object
# Qual_3         object
# Qual_4         object
# Qual_5         object
# Qual_6         object
# Qual_7         object
# Qual_8         object
# Qual_9         object
# Qual_10        object
# Qual_11        object
# Qual_12        object
# Qual_13        object
# Qual_14        object
# Qual_15        object
# Qual_16        object
# Qual_17        object
# Qual_count      int64
# dtype: object

# %%
#let us drop the unwanted columns from both the training and testing dataset.
ds_train.drop(columns=['Place','Qual_1','Qual_2','Qual_3','Qual_4','Qual_5','Qual_6','Qual_7','Qual_8','Qual_9','Qual_10'],axis=1,inplace=True)         #training dataset
ds_test.drop(columns=['Place','Qual_1','Qual_2','Qual_3','Qual_4','Qual_5','Qual_6','Qual_7','Qual_8','Qual_9','Qual_10','Qual_11','Qual_12','Qual_13','Qual_14','Qual_15','Qual_16','Qual_17'],axis=1,inplace=True)                    #testing dataset

# %% [markdown]
# Place may have any values which cannot be used for training the model also the various qualifications are also not relevant in the fee prediction process. So we had dropped the unwanted columns

# %%
ds_train.head()
# Out:
#    Experience  Rating         Profile  Fees        City  Qual_count
# 0        24.0   100.0       Homeopath   100   Ernakulam           2
# 1        12.0    98.0        Ayurveda   350   Bangalore           2
# 2         9.0     0.0  ENT Specialist   300   Bangalore           2
# 3        12.0     0.0        Ayurveda   250   Bangalore           2
# 4        20.0   100.0        Ayurveda   250     Chennai           1

# %%
ds_test.head()
# Out:
#    Experience  Rating           Profile        City  Qual_count
# 0        35.0     0.0  General Medicine      Mumbai           1
# 1        31.0     0.0    ENT Specialist   Hyderabad           2
# 2        40.0    70.0    Dermatologists     Chennai           2
# 3         0.0     0.0          Ayurveda       Delhi           1
# 4        16.0   100.0           Dentist   Bangalore           2

# %%
#we have to label encode the profile and city columns in the dataset
list=['Profile','City']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list:
    ds_train[i]=le.fit_transform(ds_train[i])
    ds_test[i]=le.transform(ds_test[i])

# %%
ds_train.head()
# Out:
#    Experience  Rating  Profile  Fees  City  Qual_count
# 0        24.0   100.0        5   100     4           2
# 1        12.0    98.0        0   350     0           2
# 2         9.0     0.0        3   300     0           2
# 3        12.0     0.0        0   250     0           2
# 4        20.0   100.0        0   250     1           1

# %%
ds_test.head()
# Out:
#    Experience  Rating  Profile  City  Qual_count
# 0        35.0     0.0        4     6           1
# 1        31.0     0.0        3     5           2
# 2        40.0    70.0        2     1           2
# 3         0.0     0.0        0     3           1
# 4        16.0   100.0        1     0           2

# %%
#lets check the cotrelation
sns.heatmap(ds_train.corr(),annot=True)

# %% [markdown]
# ### Inference
# 1. Qualification Count has the highest correlation than other attributes.
# 2. City has the highest negative correlation among other attributes.

# %%
#summary satistics of train dataset
ds_train.describe()
# Out:
#         Experience       Rating      Profile         Fees         City  \
# count  5961.000000  5961.000000  5961.000000  5961.000000  5961.000000
# mean     17.303976    42.217245     2.441872   307.944640     3.079517
# std      11.142798    47.340934     1.658014   190.920373     2.313018
# min       0.000000     0.000000     0.000000     5.000000     0.000000
# 25%       9.000000     0.000000     1.000000   150.000000     1.000000
# 50%      14.000000     0.000000     2.000000   300.000000     3.000000
# 75%      23.000000    96.000000     4.000000   500.000000     5.000000
# max      66.000000   100.000000     5.000000   950.000000     8.000000
#
#         Qual_count
# count  5961.000000
# mean      1.993625
# std       0.964274
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max      10.000000

# %%
#summary statistics of test dataset
ds_test.describe()
# Out:
#         Experience       Rating      Profile         City   Qual_count
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean     17.874685    42.634122     2.508807     3.037745     2.031203
# std      11.366764    47.284014     1.654223     2.277143     0.991420
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       9.000000     0.000000     1.000000     1.000000     1.000000
# 50%      15.000000     0.000000     2.000000     3.000000     2.000000
# 75%      24.000000    96.000000     4.000000     5.000000     2.000000
# max      65.000000   100.000000     5.000000     8.000000    17.000000

# %% [markdown]
# There is not much difference between the 75 th percentile and max value.Also we cannot treat outliers because they may be some of the valid datapoints which get removed while treating outliers.

# %% [markdown]
# ### Model Training

# %%
#we split the data into target and input variables
ds_x=ds_train.drop(columns='Fees',axis=1)
y=ds_train['Fees']

# %%
#input data
ds_x.head()
# Out:
#    Experience  Rating  Profile  City  Qual_count
# 0        24.0   100.0        5     4           2
# 1        12.0    98.0        0     0           2
# 2         9.0     0.0        3     0           2
# 3        12.0     0.0        0     0           2
# 4        20.0   100.0        0     1           1

# %%
#target variable
y.head()
# Out:
# 0    100
# 1    350
# 2    300
# 3    250
# 4    250
# Name: Fees, dtype: int64

# %%
# Using standard scaler we standardise the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)
x=pd.DataFrame(x,columns=ds_x.columns)

# %%
#splitting the input and target variable into test and train data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35,random_state=57)
print(x_train.shape,'\t',x_test.shape)
print('\n')
print(y_train.shape,'\t',y_test.shape)
# Out:
# (3874, 5) 	 (2087, 5)
#
#
# (3874,) 	 (2087,)

# %%
#importing libraries for models and error metrics
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#importing boosting models
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
 
#importing cross validation and grid search cv
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
#creating a for loop for all the models
model=[LinearRegression(),Lasso(),Ridge(),ElasticNet(),SVR(),KNeighborsRegressor(),DecisionTreeRegressor(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]
for m in model:
    m.fit(x_train,y_train)
    print('score of ',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Metrics:')
    print('mean absolute error:',mean_absolute_error(y_test,predm))
    print('mean squared error:',mean_squared_error(y_test,predm))
    print('r2 score:',r2_score(y_test,predm))
    print('END OF THE MODEL----------------------------------- ')
    print('\n')
# Out:
# score of  LinearRegression() is: 0.08878953847189341
# Metrics:
# mean absolute error: 147.83768698165312
# mean squared error: 33422.88694317121
# r2 score: 0.09379228740039725
# END OF THE MODEL-----------------------------------
#
#
# score of  Lasso() is: 0.08865344058207159
# Metrics:
# mean absolute error: 148.06405241461846
# mean squared error: 33439.4856708851
# r2 score: 0.09334223965020594
# END OF THE MODEL-----------------------------------
#
#
# score of  Ridge() is: 0.0887895333787464
# Metrics:
# mean absolute error: 147.83930749995756
# mean squared error: 33422.97466507424
# r2 score: 0.09378990896237571
# END OF THE MODEL-----------------------------------
#
#
# score of  ElasticNet() is: 0.0794810529808484
# Metrics:
# mean absolute error: 150.23972278043786
# mean squared error: 33864.06295460111
# r2 score: 0.08183051088326143
# END OF THE MODEL-----------------------------------
#
#
# score of  SVR() is: 0.06174225503239217
# Metrics:
# mean absolute error: 146.43087880588448
# mean squared error: 34829.40359717497
# r2 score: 0.05565685517620944
# END OF THE MODEL-----------------------------------
#
#
# score of  KNeighborsRegressor() is: 0.3713852225292934
# Metrics:
# mean absolute error: 143.89506468615238
# mean squared error: 35230.75563009104
# r2 score: 0.044774841653126174
# END OF THE MODEL-----------------------------------
#
#
# score of  DecisionTreeRegressor() is: 0.8502703382087593
# Metrics:
# mean absolute error: 172.63472288771763
# mean squared error: 56111.184901240485
# r2 score: -0.5213643455475228
# END OF THE MODEL-----------------------------------
#
#
# score of  RandomForestRegressor() is: 0.761208657725342
# Metrics:
# mean absolute error: 144.42459832855937
# mean squared error: 35539.67742401606
# r2 score: 0.03639892509268816
# END OF THE MODEL-----------------------------------
#
#
# score of  AdaBoostRegressor() is: 0.12512881479510574
# Metrics:
# mean absolute error: 147.06572478891133
# mean squared error: 31959.04117752693
# r2 score: 0.13348210609076472
# END OF THE MODEL-----------------------------------
#
#
# score of  GradientBoostingRegressor() is: 0.2440428013892173
# Metrics:
# mean absolute error: 134.16090419629074
# mean squared error: 29063.702580791207
# r2 score: 0.21198454579354742
# END OF THE MODEL-----------------------------------

# %%
#lets check the cross validation scores
model=[LinearRegression(),Lasso(),Ridge(),ElasticNet(),SVR(),KNeighborsRegressor(),DecisionTreeRegressor(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]
for m in model:
    score=cross_val_score(m,x,y,cv=10,scoring='r2')
    print('Model:',m)
    print('Score:',score)
    print('Mean Score:',score.mean())
    print('Standard Deviation:',score.std())
    print('#########################################################')
    print('\n')
# Out:
# Model: LinearRegression()
# Score: [0.08847606 0.08724941 0.11340604 0.09291086 0.08282812 0.10064385
#  0.06318398 0.06770847 0.10063842 0.08402037]
# Mean Score: 0.08810655762124069
# Standard Deviation: 0.01435278141523612
# #########################################################
#
#
# Model: Lasso()
# Score: [0.08788445 0.08651031 0.11254055 0.0933533  0.08318889 0.0995208
#  0.06463448 0.06883753 0.09959703 0.08421363]
# Mean Score: 0.08802809631619765
# Standard Deviation: 0.013605043493888832
# #########################################################
#
#
# Model: Ridge()
# Score: [0.08847626 0.08725049 0.113403   0.09290987 0.0828269  0.10063942
#  0.06319011 0.06771354 0.10063557 0.08402394]
# Mean Score: 0.08810690884522186
# Standard Deviation: 0.014349728051882513
# #########################################################
#
#
# Model: ElasticNet()
# Score: [0.07897265 0.07907581 0.09740622 0.08162506 0.072727   0.08436985
#  0.06378189 0.06684697 0.08595591 0.07868789]
# Mean Score: 0.07894492330942199
# Standard Deviation: 0.00917393492279459
# #########################################################
#
#
# Model: SVR()
# Score: [0.08608052 0.08465238 0.07746138 0.04607944 0.05433246 0.0991756
#  0.05224532 0.04638209 0.05621564 0.10192135]
# Mean Score: 0.07045461716991064
# Standard Deviation: 0.020682787375963668
# #########################################################
#
#
# Model: KNeighborsRegressor()
# Score: [ 0.001937   -0.03008712  0.09435563 -0.00022602  0.09520781  0.06468427
#   0.06096221  0.03052596  0.02869732  0.02396557]
# Mean Score: 0.037002263970270455
# Standard Deviation: 0.03926199258303451
# #########################################################
#
#
# Model: DecisionTreeRegressor()
# Score: [-0.45723106 -0.44140945 -0.46468972 -0.38898752 -0.48540384 -0.47907101
#  -0.4522156  -0.48554944 -0.42102245 -0.52127912]
# Mean Score: -0.45968592036077516
# Standard Deviation: 0.03523331393268795
# #########################################################
#
#
# Model: RandomForestRegressor()
# Score: [ 0.03373892  0.02467728  0.06659059  0.01549675  0.07972048  0.0244333
#   0.09113298  0.02491467  0.02593278 -0.0406097 ]
# Mean Score: 0.03460280496238642
# Standard Deviation: 0.035564245796205346
# #########################################################
#
#
# Model: AdaBoostRegressor()
# Score: [0.11105106 0.10693228 0.14747406 0.12270746 0.13498009 0.12426569
#  0.13702489 0.11923267 0.13137765 0.09756841]
# Mean Score: 0.12326142686615804
# Standard Deviation: 0.014395472561585042
# #########################################################
#
#
# Model: GradientBoostingRegressor()
# Score: [0.20316586 0.21488041 0.21667196 0.17476964 0.22736241 0.21552749
#  0.21234923 0.1719956  0.20696438 0.1797147 ]
# Mean Score: 0.20234016776147082
# Standard Deviation: 0.01864875626355036
# #########################################################

# %% [markdown]
# Of all the above models Gradient Boosting Regressor shows the highest r2 score.

# %%
#using grid search cv
gbr=GradientBoostingRegressor(random_state=57)
parameters = {"criterion": ["friedman_mse",  "mae"],
              "max_features":["log2","sqrt"]}
grid = GridSearchCV(estimator=gbr, param_grid=parameters,cv=10,scoring='r2') 
grid.fit(x,y)
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2'}

# %%
gbr=GradientBoostingRegressor(random_state=57,criterion='friedman_mse',max_features='log2')
parameters = {'learning_rate': [0.01,0.1,1],
              'n_estimators': [10,100,1000]}
grid = GridSearchCV(estimator=gbr, param_grid=parameters,cv=10,scoring='r2') 
grid.fit(x,y)
grid.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
#training the Gradient Boosting Regressor model with best parameters
gbr=GradientBoostingRegressor(random_state=57,criterion='friedman_mse',max_features='log2',learning_rate= 0.01,n_estimators=1000)
gbr.fit(x_train,y_train)
print('score:',gbr.score(x_train,y_train))
predgbr=gbr.predict(x_test)
print('\n')
print('mean absolute error:',mean_absolute_error(y_test,predgbr))
print('mean squared error:',mean_squared_error(y_test,predgbr))
print('r2 score:',r2_score(y_test,predgbr))
# Out:
# score: 0.23918463661097256
#
#
# mean absolute error: 134.3254443218765
# mean squared error: 29020.698492490268
# r2 score: 0.2131505323391707

# %% [markdown]
# After parameter tuning r2 score has been improved from 0.211 to 0.213.

# %% [markdown]
# ### Test data

# %%
ds_x=ds_test
ds_x
# Out:
#       Experience  Rating  Profile  City  Qual_count
# 0           35.0     0.0        4     6           1
# 1           31.0     0.0        3     5           2
# 2           40.0    70.0        2     1           2
# 3            0.0     0.0        0     3           1
# 4           16.0   100.0        1     0           2
# ...          ...     ...      ...   ...         ...
# 1982        10.0     0.0        0     0           2
# 1983         4.0     0.0        2     1           3
# 1984         9.0     0.0        4     1           2
# 1985        12.0    98.0        1     0           1
# 1986         8.0     0.0        2     1           3
#
# [1987 rows x 5 columns]

# %%
#applying standard scaling
x=sc.transform(ds_x)
x=pd.DataFrame(x,columns=ds_x.columns)

# %%
#predicting the output
Predictgbr=gbr.predict(x)

# %%
#predicted output
pd.DataFrame(Predictgbr)
# Out:
#                0
# 0     223.533960
# 1     368.442219
# 2     342.752692
# 3     227.408117
# 4     254.240028
# ...          ...
# 1982  257.127774
# 1983  350.273298
# 1984  310.167685
# 1985  228.125194
# 1986  343.399158
#
# [1987 rows x 1 columns]

# %% [markdown]
# ## Saving the model and result

# %%
#saving the GBR model
import joblib
joblib.dump(gbr,'Doctor_fees.pkl')
# Out:
# ['Doctor_fees.pkl']

# %%
#saving the output to csv file
pred_OP=pd.DataFrame(Predictgbr)
pred_OP.to_csv('Doctor_Fees_predictions.csv')
