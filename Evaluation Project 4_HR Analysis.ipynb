# %% [markdown]
# # EVALUATION PROJECT 4
# HR ANALYSIS DATASET

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#creating dataframe from the csv file
ds=pd.read_csv('HR_data.csv')
ds
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#lets find out the different attributes present
ds.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#lets find the datatypes of each column
ds.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# we have 9 categorical variables of object type and rest others are numerical variables of integer datatype

# %%
# checking for null values
ds.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are no missing datas in any of the columns

# %%
#let us look into the categorical data
#attrition
print('Attrition:',ds['Attrition'].unique())
#business travel
print('\n')
print('BusinessTravel:',ds['BusinessTravel'].unique())
#department
print('\n')
print('Department:',ds['Department'].unique())
#education field
print('\n')
print('EducationField:',ds['EducationField'].unique())
#gender
print('\n')
print('Gender:',ds['Gender'].unique())
#job role
print('\n')
print('JobRole:',ds['JobRole'].unique())
#marital status
print('\n')
print('MaritalStatus:',ds['MaritalStatus'].unique())
#over 18
print('\n')
print('Over18:',ds['Over18'].unique())
#over time
print('\n')
print('OverTime',ds['OverTime'].unique())
# Out:
# Attrition: ['Yes' 'No']
#
#
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# Department: ['Sales' 'Research & Development' 'Human Resources']
#
#
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
#
# Gender: ['Female' 'Male']
#
#
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
#
# MaritalStatus: ['Single' 'Married' 'Divorced']
#
#
# Over18: ['Y']
#
#
# OverTime ['Yes' 'No']

# %% [markdown]
# Let us explore the attrition factors graphically

# %%
#count of attrition with respect to ages
plt.figure(figsize=(10,10))
sns.countplot(x='Age',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# Inference:
#
# 1. max attrition is in between age 26 - 35
#
# 2. attrition starts from the age 18 and there is a 50% chance of person likely to stay within the company when he is appointed at the age of 18
#
# 3. after the age of 21 the number of leavers are less compared to those who stay within the company.
#
# 4. attrition level is minimum after the age of 45 and we can see that the maximum age is 58 where a person leaves the company beyond that there is no attrition seen.

# %%
#count of attrition with respect to business travels
sns.countplot(x='BusinessTravel',hue='Attrition',data=ds)

# %% [markdown]
# Attrition is more in the cases of persons travelling rarely and is much lesser in persons going for business trips frequently and is very less for the non-travel people.

# %%
#total value of counts 
ds['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#plotting dailyrate with respect to leavers
sns.scatterplot(x=range(0,237),y='DailyRate',data=ds.loc[ds['Attrition']=='Yes'])

# %% [markdown]
# Maximum attrition is for daily rate less than 900

# %%
#finding the count of people leaving with respect to department
sns.countplot(x='Department',hue='Attrition',data=ds)

# %% [markdown]
# People working in the RnD department have higher attrition rate as compared with other two departments.Also people working in the Human resources department have a less chance of leaving.

# %%
#relationship of distance from home with attrition
sns.countplot(x='DistanceFromHome',hue='Attrition',data=ds)

# %% [markdown]
# Majority of people whether they leave or not are within a distance of 10 miles from home. As the distance further increases the amount of people staying within the company is decreasing.

# %%
#lets find the distinct values present in education column
ds['Education'].value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %% [markdown]
# The education is specified as 5 different categories of which majority of people belong to 3rd category.

# %%
#find the countplot of attrition regarding education
sns.countplot(x='Education',hue='Attrition',data=ds)

# %% [markdown]
# maximum amount of people leaving are corresponding to the 3rd category.

# %%
#checking for distinct values in education field column
ds['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#attrition count with respecct to education field
sns.countplot(x='EducationField',hue='Attrition',data=ds)

# %% [markdown]
# Majority of the people belong to life sciences and Medical field. Attrition rate is almost same for marketing and technical degree field

# %%
#employee count is a constant value hence no relevance is there with the target 
ds['EmployeeCount'].value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
#checking for uniquness in environment satisfaction column
ds['EnvironmentSatisfaction'].value_counts()
#finding relation with attrition count
sns.countplot(x='EnvironmentSatisfaction',hue='Attrition',data=ds)

# %% [markdown]
# more attrition is found in 1st level of satisfaction.

# %%
#let us find out the attrition based on gender
sns.countplot(x='Gender',hue='Attrition',data=ds)

# %% [markdown]
# Total number of female employees are approx 500 out of which nearly 100 left,whereas out of approximately 700 male employees nearly 150 left. Thus female employees have ahigh chance of leaving

# %%
#satisfaction level of job
sns.countplot(x='JobSatisfaction',hue='Attrition',data=ds)

# %% [markdown]
# The 4th category are highly satisfied as their staying rate is much high and leaving rate is much low

# %%
#marital status in respect with attrition
sns.countplot(x='MaritalStatus',hue='Attrition',data=ds)

# %% [markdown]
# Mostly the unmarried ones are more prone to leaving the company.

# %%
#relation of monthly income with attrition
sns.scatterplot(x=range(0,237),y='MonthlyIncome',data=ds.loc[ds['Attrition']=='Yes'])

# %% [markdown]
# People with monthly income less than 7500 are mostly leaving the company.

# %%
#relation of Number of companies worked to the attrition
sns.countplot(x='NumCompaniesWorked',hue='Attrition',data=ds)

# %% [markdown]
# chance of attrition is less if the person had worked in more than 1 company

# %%
#overtime vs attrition
sns.countplot(x='OverTime',hue='Attrition',data=ds)

# %% [markdown]
# Amount of people working overtime who tend to stay within the company is 300 and those who leave the company is around 110. so there is a high risk that people working overtime have high chances of leaving the company.

# %%
#finding the percentage hikes of salary
print(ds['PercentSalaryHike'].value_counts())
#finding whether there is a relation with attrition level
plt.figure(figsize=(10,10))
sns.countplot(x='PercentSalaryHike',hue='Attrition',data=ds)
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64

# %% [markdown]
# people having higher salary hike of 25% are very much less likely to leave the company.

# %%
#total working years with respect to attrition
plt.figure(figsize=(10,10))
sns.countplot(x='TotalWorkingYears',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# Chances of people leaving the company is very high if the total working years is less than 2.

# %%
#years at company with respect to attrition
plt.figure(figsize=(10,10))
sns.countplot(x='YearsAtCompany',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# The chance of a person leaving the company is very less if he had completed 10 years within the company. Most of the people who leave the company are those who gained an experience of 1 year.

# %%
#Years in current role versus attrition
plt.figure(figsize=(10,10))
sns.countplot(x='YearsInCurrentRole',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# After 7 years attrition is less seen as years progress in the current role.

# %%
#years since last promotion to the attrition 
plt.figure(figsize=(10,10))
sns.countplot(x='YearsSinceLastPromotion',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# As the years since last promotion increases there is no increase in attrition level seen. Hence years since last promotion is not an important aspect for attrition.

# %%
#years with current manager
plt.figure(figsize=(10,10))
sns.countplot(x='YearsWithCurrManager',hue='Attrition',data=ds)
plt.show()

# %% [markdown]
# Attrition is significant for the first two years of working with the current manager and thereafter it is less seen as the years progresses.This is a major factor as the employee builds a strong relationship with the manager and hence maximises the company growth.

# %% [markdown]
# Let us transform the categorical variables into numeric datas

# %%
#creating a dictionary
value={'Yes':1,'No':0}
#transforming attrition into numeric
ds['Attrition']=ds['Attrition'].apply(lambda x: value[x])
#transforming overtime into numeric
ds['OverTime']=ds['OverTime'].apply(lambda x: value[x])
print(ds['Attrition'].value_counts())
print(ds['OverTime'].value_counts())
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# 0    1054
# 1     416
# Name: OverTime, dtype: int64

# %%
#the rest of the categorical datas we can label encode them.
from sklearn.preprocessing import LabelEncoder
list=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']
le=LabelEncoder()
for i in list:
    ds[i]=le.fit_transform(ds[i])

# %%
ds
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
#let us drop the irrelevant columns employee count,employee number,standard hours and over 18.
ds.drop(columns=['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1,inplace=True)
ds.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#let us find the shape of dataframe
ds.shape
# Out:
# (1470, 31)

# %%
#lets check for summary statistics
ds.describe()
#since there are many columns it is difficult to summarize from this table
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           9.192517     2.912925        2.247619                 2.721769
# ...

# %%
#lets find the correlation
ds.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# ...

# %%
#graphical visualization using heatmap
plt.figure(figsize=(10,10))
sns.heatmap(ds.corr())
plt.show()

# %% [markdown]
# lets check for outliers

# %%
#plotting the boxplot for all attributes to check the outliers
for i in ds.columns:
    plt.figure()
    sns.boxplot(ds[i],orient="v")

# %%
#there are a litle outliers present in some columns,lets treat them
#removing the outliers
from scipy.stats import zscore
z_score=abs(zscore(ds))
print(ds.shape)

ds_final=ds.loc[(z_score<3).all(axis=1)]
print(ds_final.shape)
# Out:
# (1470, 31)
# (1387, 31)

# %%
ds=ds_final
ds.shape
# Out:
# (1387, 31)

# %%
#There are certain attributes lightly skewed
#lets visualize graphically
for i in ds.columns:
    plt.figure()
    sns.distplot(ds[i])

# %% [markdown]
# Let us seperate the Attrition from the dataframe and perform PCA.Since we have 30 columns we reduce them by pca

# %%
#seperating target variable
y=ds['Attrition']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int64

# %%
ds_ip=ds.drop(columns='Attrition',axis=1)
ds_ip
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=10)
ds_ip=pca.fit_transform(ds_ip)

# %%
#The above pca process delivers the result as numpy array,hence we create a dataframe.
ds_x=pd.DataFrame(data=ds_ip)
ds_x
# Out:
#                  0            1           2          3          4          5  \
# 0      5168.608568  -239.678736 -305.408645 -28.062619   3.571827  -8.820315
# 1     10558.920040 -1322.903172  504.818567   4.082791  13.447229  -0.995581
# 2    -12057.819818 -3452.390946 -559.194598 -24.968193   3.875557  -7.254987
# 3      8721.261414 -3467.951227 -612.743216  10.521651   0.461985  -6.325768
# 4      2223.326528 -2650.094822  201.973097  26.078534  -5.859329  -7.415983
# ...            ...          ...         ...        ...        ...        ...
# 1382  -2151.682132 -3370.902043  -86.322387  25.068328   6.749388  14.454262
# 1383   7306.431446  3673.887023  193.975445  23.092812  -2.135960  -3.202577
# 1384  -9117.265668   480.396886  667.897795 -21.142871 -10.561579  -5.368378
# 1385  -1086.439782  -591.969773 -217.245644   2.966700  15.493808  -6.495603
# 1386  -4137.956528 -1457.500874  179.745690 -15.968144  -1.960989  -1.515949
#
#              6         7         8         9
# ...

# %%
#Now using standard scaler we standardise the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)
x=pd.DataFrame(x,columns=ds_x.columns)

# %%
x
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.733457 -0.056518 -0.758648 -1.384459  0.426219 -1.091616 -0.143474
# 1     1.498376 -0.311948  1.253991  0.201423  1.604632 -0.123215  0.594418
# 2    -1.711079 -0.814094 -1.389063 -1.231796  0.462463 -0.897888 -1.086431
# 3     1.237601 -0.817763 -1.522080  0.519082  0.055128 -0.782887  0.658565
# 4     0.315504 -0.624908  0.501710  1.286575 -0.699182 -0.917813 -0.431066
# ...        ...       ...       ...       ...       ...       ...       ...
# 1382 -0.305337 -0.794879 -0.214428  1.236736  0.805391  1.788882  0.083503
# 1383  1.036828  0.866324  0.481843  1.139275 -0.254880 -0.396356  0.001815
# 1384 -1.293796  0.113280  1.659086 -1.043076 -1.260293 -0.664399 -0.183560
# 1385 -0.154173 -0.139590 -0.539647  0.146361  1.848846 -0.803906  0.721608
# 1386 -0.587202 -0.343687  0.446496 -0.787782 -0.234001 -0.187616 -0.377941
#
#              7         8         9
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int64

# %%
print(x.shape,'\t',y.shape)
# Out:
# (1387, 10) 	 (1387,)

# %%
#splitting the input and target variable into test and train data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)
print(x_train.shape,'\t',x_test.shape)
# Out:
# (970, 10) 	 (417, 10)

# %%
print(y_train.shape,'\t',y_test.shape)
# Out:
# (970,) 	 (417,)

# %%
#importing libraries for models and error metrics
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#creating a for loop for all the models
model=[LogisticRegression(),SVC(),KNeighborsClassifier(),DecisionTreeClassifier(),GaussianNB()]
for m in model:
    m.fit(x_train,y_train)
    print('score of ',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Metrics:')
    print('Accuracy Score:',accuracy_score(y_test,predm))
    print('Confusion Matrix:',confusion_matrix(y_test,predm))
    print('Classification Report:',classification_report(y_test,predm))
    print('END OF THE MODEL----------------------------------- ')
    print('\n')
# Out:
# score of  LogisticRegression() is: 0.8402061855670103
# Metrics:
# Accuracy Score: 0.8249400479616307
# Confusion Matrix: [[342   3]
#  [ 70   2]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90       345
#            1       0.40      0.03      0.05        72
#
#     accuracy                           0.82       417
#    macro avg       0.62      0.51      0.48       417
# weighted avg       0.76      0.82      0.76       417
#
# END OF THE MODEL-----------------------------------
#
#
# score of  SVC() is: 0.8391752577319588
# Metrics:
# Accuracy Score: 0.8249400479616307
# Confusion Matrix: [[344   1]
#  [ 72   0]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.90       345
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.82       417
# ...

# %% [markdown]
# Of the above models Logistic Regression and svc have high accuracy score.Now let us do parameter tuning.

# %%
#parameter tuning of Logistic Regression
from sklearn.model_selection import GridSearchCV
lg=LogisticRegression()
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}               # l1----- lasso
lg_cv=GridSearchCV(lg,grid,cv=10)                                   # l2----- ridge
lg_cv.fit(x_train,y_train)
lg_cv.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2'}

# %%
#training the logistic regression model with best parameters
lg=LogisticRegression(C=0.1,penalty='l2')
lg.fit(x_train,y_train)
print('score:',lg.score(x_train,y_train))
predlg=lg.predict(x_test)
print('\n')
print('accuracy score:',accuracy_score(y_test,predlg))
print('confusion matrix:',confusion_matrix(y_test,predlg))
print('classification report:',classification_report(y_test,predlg))
# Out:
# score: 0.8402061855670103
#
#
# accuracy score: 0.8273381294964028
# confusion matrix: [[344   1]
#  [ 71   1]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       345
#            1       0.50      0.01      0.03        72
#
#     accuracy                           0.83       417
#    macro avg       0.66      0.51      0.47       417
# weighted avg       0.77      0.83      0.75       417

# %%
#finding best parameters for SVM using gridsearch
# defining parameter range
svc=SVC()
parameters = {'C': [0.1, 1, 10, 100],  
              'gamma': [1, 0.1, 0.01, 0.001], 
              'kernel': ['rbf','linear','ploy']}  
  
grid = GridSearchCV(estimator=svc, param_grid=parameters,scoring='accuracy') 
  
# fitting the model for grid search 
grid.fit(x, y) 
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}

# %%
#training the svm model with best parameters
svc=SVC(C=0.1,gamma=1,kernel='rbf')
svc.fit(x_train,y_train)
print('score:',svc.score(x_train,y_train))
predsvc_class=svc.predict(x_test)
print('\n')
print('Accuracy Score:',accuracy_score(y_test,predsvc_class))
print('Confusion Matrix:',confusion_matrix(y_test,predsvc_class))
print('Classification Report:',classification_report(y_test,predsvc_class))
# Out:
# score: 0.8381443298969072
#
#
# Accuracy Score: 0.8273381294964028
# Confusion Matrix: [[345   0]
#  [ 72   0]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       345
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.83       417
#    macro avg       0.41      0.50      0.45       417
# weighted avg       0.68      0.83      0.75       417

# %% [markdown]
# Now let us look the ensemble methods

# %% [markdown]
# ## Ensemble Methods

# %%
#using Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=20,random_state=75)
rfc.fit(x_train,y_train)
print('score:',rfc.score(x_train,y_train))
predrfc=rfc.predict(x_test)
print('\n')
print('Accuracy Score:',accuracy_score(y_test,predrfc))
print('Confusion Matrix:',confusion_matrix(y_test,predrfc))
print('Classification Report:',classification_report(y_test,predrfc))
# Out:
# score: 0.9969072164948454
#
#
# Accuracy Score: 0.8465227817745803
# Confusion Matrix: [[340   5]
#  [ 59  13]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       345
#            1       0.72      0.18      0.29        72
#
#     accuracy                           0.85       417
#    macro avg       0.79      0.58      0.60       417
# weighted avg       0.83      0.85      0.81       417

# %%
from sklearn.ensemble import AdaBoostClassifier
svc_adb=SVC()
adbc=AdaBoostClassifier(base_estimator=svc_adb,algorithm='SAMME',n_estimators=20,learning_rate=0.1,random_state=42)
adbc.fit(x_train,y_train)
print('score:',adbc.score(x_train,y_train))
predadbc=adbc.predict(x_test)
print('\n')
print('Accuracy Score:',accuracy_score(y_test,predadbc))
print('Confusion Matrix:',confusion_matrix(y_test,predadbc))
print('Classification Report:',classification_report(y_test,predadbc))
# Out:
# score: 0.8381443298969072
#
#
# Accuracy Score: 0.8273381294964028
# Confusion Matrix: [[345   0]
#  [ 72   0]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       345
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.83       417
#    macro avg       0.41      0.50      0.45       417
# weighted avg       0.68      0.83      0.75       417

# %% [markdown]
# The Random forest classifier has the best accuracy score. Hence we can consider this as the best model and check for cross validation scores.

# %%
#cross validating Random forest classifier
from sklearn.model_selection import cross_val_score
score=cross_val_score(rfc,x,y,cv=10,scoring='accuracy')
print('Score:',score)
print('Mean Score:',score.mean())
print('Standard Deviation:',score.std())
# Out:
# Score: [0.81294964 0.84892086 0.83453237 0.83453237 0.84892086 0.83453237
#  0.82014388 0.84782609 0.84057971 0.85507246]
# Mean Score: 0.8378010634970284
# Standard Deviation: 0.01270923018335435

# %% [markdown]
# The mean cross vallidation score is about 0.83, that is the model is well fit and can be considered as the suitable model for this dataset.

# %% [markdown]
# AUC ROC Curve

# %%
from sklearn.metrics import roc_auc_score,roc_curve
y_pred_prob=rfc.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([0.45, 0.  , 0.2 , 0.65, 0.2 , 0.15, 0.7 , 0.05, 0.05, 0.  , 0.2 ,
#        0.2 , 0.8 , 0.1 , 0.15, 0.3 , 0.25, 0.35, 0.25, 0.1 , 0.1 , 0.15,
#        0.5 , 0.1 , 0.25, 0.1 , 0.35, 0.65, 0.05, 0.05, 0.  , 0.15, 0.3 ,
#        0.2 , 0.45, 0.05, 0.3 , 0.05, 0.3 , 0.1 , 0.7 , 0.25, 0.2 , 0.25,
#        0.15, 0.2 , 0.1 , 0.25, 0.1 , 0.2 , 0.05, 0.25, 0.3 , 0.  , 0.05,
#        0.4 , 0.05, 0.25, 0.3 , 0.5 , 0.  , 0.25, 0.  , 0.05, 0.15, 0.05,
#        0.2 , 0.05, 0.1 , 0.  , 0.15, 0.2 , 0.2 , 0.5 , 0.15, 0.  , 0.5 ,
#        0.25, 0.  , 0.25, 0.05, 0.25, 0.2 , 0.3 , 0.45, 0.  , 0.1 , 0.3 ,
#        0.  , 0.15, 0.6 , 0.3 , 0.7 , 0.1 , 0.1 , 0.15, 0.1 , 0.2 , 0.05,
#        0.  , 0.05, 0.1 , 0.2 , 0.05, 0.2 , 0.05, 0.2 , 0.2 , 0.15, 0.15,
#        0.05, 0.3 , 0.1 , 0.  , 0.2 , 0.25, 0.05, 0.2 , 0.1 , 0.1 , 0.05,
#        0.1 , 0.05, 0.6 , 0.  , 0.15, 0.  , 0.35, 0.1 , 0.15, 0.15, 0.15,
#        0.1 , 0.4 , 0.1 , 0.3 , 0.3 , 0.15, 0.1 , 0.  , 0.05, 0.25, 0.25,
# ...

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest Classifier')
plt.show()

# %%
auc_score=roc_auc_score(y_test,rfc.predict(x_test))
print(auc_score)
# Out:
# 0.5830314009661836

# %% [markdown]
# The probability of predicting that there is an attrition by using RFC model is 0.58

# %% [markdown]
# ## Saving the model and result

# %%
#saving the RFC model
import joblib
joblib.dump(rfc,'HR_Attrition.pkl')
# Out:
# ['HR_Attrition.pkl']

# %%
#saving the output to csv file
pred_OP=pd.DataFrame(predrfc)
pred_OP.to_csv('HR_Attrition_prediction.csv')
